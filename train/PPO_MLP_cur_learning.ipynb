# %%
from flappy_bird_gymnasium.envs.flappy_bird_env import FlappyBirdEnv
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.logger import configure
import os
from classes import CustomFlappyBirdEnv_gap200, CustomFlappyBirdEnv_gap150, CustomFlappyBirdEnv_gap125, CustomFlappyBirdEnv_std

# %%
# Log-Directory und Dateiname für den Callback festlegen
log_dir = "../logs/"
os.makedirs(log_dir, exist_ok=True)
custom_log_file = os.path.join(log_dir, "Curriculum_Learning")

# Configure the logger to save data to a specific folder
new_logger = configure(custom_log_file, ["stdout", "csv"])
# Out:
# Logging to ../logs/Curriculum_Learning

# %%
gym.envs.registration.register(
    id='CustomFlappyBird-v0',
    entry_point='__main__:CustomFlappyBirdEnv_gap200',
    max_episode_steps=10000000,
)

# Environment erstellen und mit VecMonitor wrappen
env = make_vec_env("CustomFlappyBird-v0", n_envs=4, env_kwargs={'render_mode': 'rgb_array', 'use_lidar': False})

# %%
# PPO Modell definieren
model = PPO(
    "MlpPolicy", 
    env, 
    learning_rate=3e-4, 
    n_steps=256, 
    batch_size=64, 
    n_epochs=10, 
    gamma=0.99, 
    ent_coef=0.01,
    verbose=1,
    device='cuda'
)

# Attach the new logger to the model
model.set_logger(new_logger)

# Modell trainieren mit Callback
model.learn(total_timesteps=500000)

# Modell speichern
model.save("../models/PPO_MLP_gap200_500k")
# Out:
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.62    |
# | time/              |          |
# |    fps             | 1258     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1024     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -7.12       |
# | time/                   |             |
# |    fps                  | 700         |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.007172595 |
# |    clip_fraction        | 0.0119      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | 0.0274      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.844       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.000726   |
# |    value_loss           | 3.74        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -6.78        |
# | time/                   |              |
# |    fps                  | 639          |
# |    iterations           | 3            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0018075267 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.683       |
# |    explained_variance   | 0.367        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.766        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000692    |
# |    value_loss           | 2.16         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -6.32       |
# | time/                   |             |
# |    fps                  | 621         |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009364021 |
# |    clip_fraction        | 0.0723      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.656      |
# |    explained_variance   | 0.552       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.494       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00431    |
# |    value_loss           | 1.66        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -5.8        |
# | time/                   |             |
# |    fps                  | 610         |
# |    iterations           | 5           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.012617052 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.603      |
# |    explained_variance   | 0.53        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.576       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0172     |
# |    value_loss           | 1.66        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50.1         |
# |    ep_rew_mean          | -4.31        |
# | time/                   |              |
# |    fps                  | 598          |
# |    iterations           | 6            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0061438363 |
# |    clip_fraction        | 0.0888       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.557       |
# |    explained_variance   | 0.52         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.73         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00998     |
# |    value_loss           | 1.62         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50.1       |
# |    ep_rew_mean          | -3.05      |
# | time/                   |            |
# |    fps                  | 584        |
# |    iterations           | 7          |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 7168       |
# | train/                  |            |
# |    approx_kl            | 0.00638659 |
# |    clip_fraction        | 0.113      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.487     |
# |    explained_variance   | 0.393      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.78       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0131    |
# |    value_loss           | 1.83       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.5        |
# |    ep_rew_mean          | -1.37       |
# | time/                   |             |
# |    fps                  | 583         |
# |    iterations           | 8           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008811608 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.427      |
# |    explained_variance   | 0.538       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.428       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0132     |
# |    value_loss           | 1.25        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.8        |
# |    ep_rew_mean          | 0.267       |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 9           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.014515132 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.349      |
# |    explained_variance   | 0.648       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.465       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0181     |
# |    value_loss           | 1.12        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 51.9         |
# |    ep_rew_mean          | 1.86         |
# | time/                   |              |
# |    fps                  | 580          |
# |    iterations           | 10           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0069507044 |
# |    clip_fraction        | 0.0948       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.279       |
# |    explained_variance   | 0.56         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.305        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.012       |
# |    value_loss           | 1.05         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 53.6         |
# |    ep_rew_mean          | 2.92         |
# | time/                   |              |
# |    fps                  | 581          |
# |    iterations           | 11           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 11264        |
# | train/                  |              |
# |    approx_kl            | 0.0137717575 |
# |    clip_fraction        | 0.0519       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.259       |
# |    explained_variance   | 0.247        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.218        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00754     |
# |    value_loss           | 0.831        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 56.6         |
# |    ep_rew_mean          | 3.73         |
# | time/                   |              |
# |    fps                  | 582          |
# |    iterations           | 12           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0070069516 |
# |    clip_fraction        | 0.0548       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.217       |
# |    explained_variance   | 0.634        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.325        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00744     |
# |    value_loss           | 0.51         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 59.1        |
# |    ep_rew_mean          | 4.66        |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 13          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.004908922 |
# |    clip_fraction        | 0.0647      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.191      |
# |    explained_variance   | 0.683       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.261       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00812    |
# |    value_loss           | 0.524       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.9        |
# |    ep_rew_mean          | 5.31        |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 14          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011135827 |
# |    clip_fraction        | 0.0705      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.234      |
# |    explained_variance   | 0.5         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.442       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 1.01        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 67.5         |
# |    ep_rew_mean          | 6.08         |
# | time/                   |              |
# |    fps                  | 577          |
# |    iterations           | 15           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 0.0028057117 |
# |    clip_fraction        | 0.0314       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.197       |
# |    explained_variance   | 0.675        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.278        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00799     |
# |    value_loss           | 0.577        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 73.7         |
# |    ep_rew_mean          | 6.87         |
# | time/                   |              |
# |    fps                  | 576          |
# |    iterations           | 16           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0018148501 |
# |    clip_fraction        | 0.0401       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.169       |
# |    explained_variance   | 0.797        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.268        |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00664     |
# |    value_loss           | 0.442        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 77          |
# |    ep_rew_mean          | 7.39        |
# | time/                   |             |
# |    fps                  | 576         |
# |    iterations           | 17          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.002034372 |
# |    clip_fraction        | 0.0426      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.164      |
# |    explained_variance   | 0.759       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.236       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00667    |
# |    value_loss           | 0.638       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 81.4        |
# |    ep_rew_mean          | 7.93        |
# | time/                   |             |
# |    fps                  | 576         |
# |    iterations           | 18          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.011607583 |
# |    clip_fraction        | 0.0424      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.146      |
# |    explained_variance   | 0.455       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.885       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 1.67        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 85.1         |
# |    ep_rew_mean          | 8.39         |
# | time/                   |              |
# |    fps                  | 572          |
# |    iterations           | 19           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 19456        |
# | train/                  |              |
# |    approx_kl            | 0.0010807922 |
# |    clip_fraction        | 0.0347       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.127       |
# |    explained_variance   | 0.497        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.369        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00404     |
# |    value_loss           | 1.01         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 95.5         |
# |    ep_rew_mean          | 9.67         |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 20           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0035698996 |
# |    clip_fraction        | 0.0197       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.148       |
# |    explained_variance   | -0.638       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.251        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00158     |
# |    value_loss           | 1.57         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 104           |
# |    ep_rew_mean          | 10.7          |
# | time/                   |               |
# |    fps                  | 566           |
# |    iterations           | 21            |
# |    time_elapsed         | 37            |
# |    total_timesteps      | 21504         |
# | train/                  |               |
# |    approx_kl            | 0.00074076606 |
# |    clip_fraction        | 0.00957       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.134        |
# |    explained_variance   | 0.12          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.01          |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.0021       |
# |    value_loss           | 1.83          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 111          |
# |    ep_rew_mean          | 11.6         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 22           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0015757865 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.122       |
# |    explained_variance   | 0.202        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.77         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0033      |
# |    value_loss           | 2.29         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 117          |
# |    ep_rew_mean          | 12.3         |
# | time/                   |              |
# |    fps                  | 573          |
# |    iterations           | 23           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0051619015 |
# |    clip_fraction        | 0.0474       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0936      |
# |    explained_variance   | 0.436        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.457        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00565     |
# |    value_loss           | 1.44         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 118           |
# |    ep_rew_mean          | 12.4          |
# | time/                   |               |
# |    fps                  | 576           |
# |    iterations           | 24            |
# |    time_elapsed         | 42            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 0.00027668523 |
# |    clip_fraction        | 0.00303       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.109        |
# |    explained_variance   | -0.000538     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.367         |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.000415     |
# |    value_loss           | 2.06          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 130          |
# |    ep_rew_mean          | 14           |
# | time/                   |              |
# |    fps                  | 578          |
# |    iterations           | 25           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 0.0010634905 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0876      |
# |    explained_variance   | 0.00154      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.65         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00137     |
# |    value_loss           | 0.816        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 139          |
# |    ep_rew_mean          | 15.1         |
# | time/                   |              |
# |    fps                  | 577          |
# |    iterations           | 26           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0015889112 |
# |    clip_fraction        | 0.0306       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.11        |
# |    explained_variance   | 0.0159       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.17         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00217     |
# |    value_loss           | 3.61         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 142         |
# |    ep_rew_mean          | 15.5        |
# | time/                   |             |
# |    fps                  | 577         |
# |    iterations           | 27          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.004476438 |
# |    clip_fraction        | 0.0461      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.114      |
# |    explained_variance   | -0.0207     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.14        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00277    |
# |    value_loss           | 3.55        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | 17           |
# | time/                   |              |
# |    fps                  | 577          |
# |    iterations           | 28           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0038525248 |
# |    clip_fraction        | 0.0445       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.129       |
# |    explained_variance   | -0.0439      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.78         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00482     |
# |    value_loss           | 2.25         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 159          |
# |    ep_rew_mean          | 17.6         |
# | time/                   |              |
# |    fps                  | 579          |
# |    iterations           | 29           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 29696        |
# | train/                  |              |
# |    approx_kl            | 0.0011066769 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.103       |
# |    explained_variance   | 0.0271       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.31         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0011      |
# |    value_loss           | 2.42         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 170          |
# |    ep_rew_mean          | 18.9         |
# | time/                   |              |
# |    fps                  | 579          |
# |    iterations           | 30           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0010740228 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.119       |
# |    explained_variance   | 0.0944       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.582        |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00122     |
# |    value_loss           | 1.39         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 174          |
# |    ep_rew_mean          | 19.4         |
# | time/                   |              |
# |    fps                  | 580          |
# |    iterations           | 31           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 0.0023883474 |
# |    clip_fraction        | 0.0335       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0931      |
# |    explained_variance   | 0.172        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.12         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.002       |
# |    value_loss           | 2.68         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 20.1         |
# | time/                   |              |
# |    fps                  | 581          |
# |    iterations           | 32           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0007646737 |
# |    clip_fraction        | 0.0107       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0982      |
# |    explained_variance   | 0.313        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.351        |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000651    |
# |    value_loss           | 2.33         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 185           |
# |    ep_rew_mean          | 20.8          |
# | time/                   |               |
# |    fps                  | 582           |
# |    iterations           | 33            |
# |    time_elapsed         | 57            |
# |    total_timesteps      | 33792         |
# | train/                  |               |
# |    approx_kl            | 0.00085483043 |
# |    clip_fraction        | 0.0174        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.091        |
# |    explained_variance   | 0.304         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.572         |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.000278     |
# |    value_loss           | 1.29          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 204          |
# |    ep_rew_mean          | 23           |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 34           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0032185002 |
# |    clip_fraction        | 0.0493       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0836      |
# |    explained_variance   | 0.647        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.212        |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00847     |
# |    value_loss           | 0.572        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 209          |
# |    ep_rew_mean          | 23.7         |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 35           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 35840        |
# | train/                  |              |
# |    approx_kl            | 0.0011810483 |
# |    clip_fraction        | 0.00664      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0881      |
# |    explained_variance   | -0.0374      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.87         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -1.41e-05    |
# |    value_loss           | 3.62         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 211        |
# |    ep_rew_mean          | 23.9       |
# | time/                   |            |
# |    fps                  | 585        |
# |    iterations           | 36         |
# |    time_elapsed         | 62         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.00534972 |
# |    clip_fraction        | 0.0517     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.108     |
# |    explained_variance   | -0.0615    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.01       |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.00761   |
# |    value_loss           | 3.92       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 220          |
# |    ep_rew_mean          | 25           |
# | time/                   |              |
# |    fps                  | 587          |
# |    iterations           | 37           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 37888        |
# | train/                  |              |
# |    approx_kl            | 0.0011371733 |
# |    clip_fraction        | 0.00947      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0973      |
# |    explained_variance   | -0.0241      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.515        |
# |    n_updates            | 360          |
# |    policy_gradient_loss | 0.000274     |
# |    value_loss           | 0.923        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 227          |
# |    ep_rew_mean          | 25.9         |
# | time/                   |              |
# |    fps                  | 588          |
# |    iterations           | 38           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0011492053 |
# |    clip_fraction        | 0.0329       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.123       |
# |    explained_variance   | -0.0277      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.46         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00252     |
# |    value_loss           | 2.73         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 227         |
# |    ep_rew_mean          | 25.9        |
# | time/                   |             |
# |    fps                  | 589         |
# |    iterations           | 39          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.006712782 |
# |    clip_fraction        | 0.0444      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.11       |
# |    explained_variance   | 0.00742     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.74        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00629    |
# |    value_loss           | 1.87        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 230          |
# |    ep_rew_mean          | 26.3         |
# | time/                   |              |
# |    fps                  | 588          |
# |    iterations           | 40           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0008299941 |
# |    clip_fraction        | 0.0169       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0871      |
# |    explained_variance   | 0.332        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0394       |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00175     |
# |    value_loss           | 0.114        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 231          |
# |    ep_rew_mean          | 26.4         |
# | time/                   |              |
# |    fps                  | 588          |
# |    iterations           | 41           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 41984        |
# | train/                  |              |
# |    approx_kl            | 0.0007907046 |
# |    clip_fraction        | 0.0106       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0951      |
# |    explained_variance   | -0.00298     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.853        |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00121     |
# |    value_loss           | 2.03         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 254           |
# |    ep_rew_mean          | 29.2          |
# | time/                   |               |
# |    fps                  | 588           |
# |    iterations           | 42            |
# |    time_elapsed         | 73            |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 0.00083440315 |
# |    clip_fraction        | 0.0151        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0902       |
# |    explained_variance   | 0.0631        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0353        |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.00242      |
# |    value_loss           | 0.295         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 254           |
# |    ep_rew_mean          | 29.2          |
# | time/                   |               |
# |    fps                  | 589           |
# |    iterations           | 43            |
# |    time_elapsed         | 74            |
# |    total_timesteps      | 44032         |
# | train/                  |               |
# |    approx_kl            | 0.00066876743 |
# |    clip_fraction        | 0.0157        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0806       |
# |    explained_variance   | 0.0105        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.84          |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.00173      |
# |    value_loss           | 2.73          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 254          |
# |    ep_rew_mean          | 29.2         |
# | time/                   |              |
# |    fps                  | 590          |
# |    iterations           | 44           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0025036042 |
# |    clip_fraction        | 0.0413       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0812      |
# |    explained_variance   | 0.359        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0386       |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00685     |
# |    value_loss           | 0.0756       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 278          |
# |    ep_rew_mean          | 32.3         |
# | time/                   |              |
# |    fps                  | 591          |
# |    iterations           | 45           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 46080        |
# | train/                  |              |
# |    approx_kl            | 0.0008726538 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0838      |
# |    explained_variance   | 0.494        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0249       |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00232     |
# |    value_loss           | 0.0612       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 280          |
# |    ep_rew_mean          | 32.4         |
# | time/                   |              |
# |    fps                  | 591          |
# |    iterations           | 46           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0040832916 |
# |    clip_fraction        | 0.0373       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.104       |
# |    explained_variance   | 0.0188       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.67         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.003       |
# |    value_loss           | 2.33         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 282           |
# |    ep_rew_mean          | 32.8          |
# | time/                   |               |
# |    fps                  | 591           |
# |    iterations           | 47            |
# |    time_elapsed         | 81            |
# |    total_timesteps      | 48128         |
# | train/                  |               |
# |    approx_kl            | 0.00020134816 |
# |    clip_fraction        | 0.0113        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0902       |
# |    explained_variance   | -0.0929       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.393         |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.000337     |
# |    value_loss           | 1.07          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 297           |
# |    ep_rew_mean          | 34.6          |
# | time/                   |               |
# |    fps                  | 591           |
# |    iterations           | 48            |
# |    time_elapsed         | 83            |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.00038944787 |
# |    clip_fraction        | 0.0144        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0836       |
# |    explained_variance   | 0.0512        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.934         |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.00173      |
# |    value_loss           | 0.967         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 297          |
# |    ep_rew_mean          | 34.6         |
# | time/                   |              |
# |    fps                  | 592          |
# |    iterations           | 49           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 50176        |
# | train/                  |              |
# |    approx_kl            | 0.0006604452 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0896      |
# |    explained_variance   | 0.188        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0798       |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 1.12         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 321         |
# |    ep_rew_mean          | 37.6        |
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 50          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.002352891 |
# |    clip_fraction        | 0.0314      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0815     |
# |    explained_variance   | 0.617       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0138      |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00331    |
# |    value_loss           | 0.0637      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 337          |
# |    ep_rew_mean          | 39.5         |
# | time/                   |              |
# |    fps                  | 592          |
# |    iterations           | 51           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 52224        |
# | train/                  |              |
# |    approx_kl            | 0.0021680044 |
# |    clip_fraction        | 0.0249       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.102       |
# |    explained_variance   | 0.0119       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.968        |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00213     |
# |    value_loss           | 2.42         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 349         |
# |    ep_rew_mean          | 41          |
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 52          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.003992486 |
# |    clip_fraction        | 0.0416      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.112      |
# |    explained_variance   | 0.0573      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.82        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00305    |
# |    value_loss           | 3.17        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 352          |
# |    ep_rew_mean          | 41.4         |
# | time/                   |              |
# |    fps                  | 592          |
# |    iterations           | 53           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 54272        |
# | train/                  |              |
# |    approx_kl            | 0.0019379589 |
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0945      |
# |    explained_variance   | -0.0835      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.223        |
# |    n_updates            | 520          |
# |    policy_gradient_loss | 0.000625     |
# |    value_loss           | 1.4          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 355          |
# |    ep_rew_mean          | 41.8         |
# | time/                   |              |
# |    fps                  | 591          |
# |    iterations           | 54           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0008570489 |
# |    clip_fraction        | 0.00674      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.11        |
# |    explained_variance   | -0.06        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | 0.000416     |
# |    value_loss           | 1.38         |
# ...
# | rollout/                |             |
# |    ep_len_mean          | 2.37e+03    |
# |    ep_rew_mean          | 291         |
# | time/                   |             |
# |    fps                  | 629         |
# |    iterations           | 472         |
# |    time_elapsed         | 768         |
# |    total_timesteps      | 483328      |
# | train/                  |             |
# |    approx_kl            | 0.001775557 |
# |    clip_fraction        | 0.0332      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.144      |
# |    explained_variance   | 0.205       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0185      |
# |    n_updates            | 4710        |
# |    policy_gradient_loss | -0.000699   |
# |    value_loss           | 0.0524      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.36e+03     |
# |    ep_rew_mean          | 290          |
# | time/                   |              |
# |    fps                  | 629          |
# |    iterations           | 473          |
# |    time_elapsed         | 769          |
# |    total_timesteps      | 484352       |
# | train/                  |              |
# |    approx_kl            | 0.0030523632 |
# |    clip_fraction        | 0.0379       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.151       |
# |    explained_variance   | 0.137        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.561        |
# |    n_updates            | 4720         |
# |    policy_gradient_loss | 0.00183      |
# |    value_loss           | 1.16         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.39e+03     |
# |    ep_rew_mean          | 294          |
# | time/                   |              |
# |    fps                  | 629          |
# |    iterations           | 474          |
# |    time_elapsed         | 771          |
# |    total_timesteps      | 485376       |
# | train/                  |              |
# |    approx_kl            | 0.0018088764 |
# |    clip_fraction        | 0.0207       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.158       |
# |    explained_variance   | 0.191        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.983        |
# |    n_updates            | 4730         |
# |    policy_gradient_loss | -0.000909    |
# |    value_loss           | 1.13         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.39e+03     |
# |    ep_rew_mean          | 294          |
# | time/                   |              |
# |    fps                  | 629          |
# |    iterations           | 475          |
# |    time_elapsed         | 772          |
# |    total_timesteps      | 486400       |
# | train/                  |              |
# |    approx_kl            | 0.0015967106 |
# |    clip_fraction        | 0.0246       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.143       |
# |    explained_variance   | 0.195        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.222        |
# |    n_updates            | 4740         |
# |    policy_gradient_loss | -3.51e-05    |
# |    value_loss           | 1.33         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.39e+03     |
# |    ep_rew_mean          | 294          |
# | time/                   |              |
# |    fps                  | 629          |
# |    iterations           | 476          |
# |    time_elapsed         | 774          |
# |    total_timesteps      | 487424       |
# | train/                  |              |
# |    approx_kl            | 0.0028417679 |
# |    clip_fraction        | 0.0357       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.144       |
# |    explained_variance   | -0.488       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00606      |
# |    n_updates            | 4750         |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 0.0313       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.4e+03      |
# |    ep_rew_mean          | 295          |
# | time/                   |              |
# |    fps                  | 629          |
# |    iterations           | 477          |
# |    time_elapsed         | 776          |
# |    total_timesteps      | 488448       |
# | train/                  |              |
# |    approx_kl            | 0.0039135534 |
# |    clip_fraction        | 0.037        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.134       |
# |    explained_variance   | 0.846        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000751    |
# |    n_updates            | 4760         |
# |    policy_gradient_loss | 0.000328     |
# |    value_loss           | 0.00964      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.4e+03      |
# |    ep_rew_mean          | 295          |
# | time/                   |              |
# |    fps                  | 629          |
# |    iterations           | 478          |
# |    time_elapsed         | 777          |
# |    total_timesteps      | 489472       |
# | train/                  |              |
# |    approx_kl            | 0.0032419164 |
# |    clip_fraction        | 0.042        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.12        |
# |    explained_variance   | 0.0785       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.508        |
# |    n_updates            | 4770         |
# |    policy_gradient_loss | -0.00278     |
# |    value_loss           | 1.83         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 295         |
# | time/                   |             |
# |    fps                  | 629         |
# |    iterations           | 479         |
# |    time_elapsed         | 779         |
# |    total_timesteps      | 490496      |
# | train/                  |             |
# |    approx_kl            | 0.006825162 |
# |    clip_fraction        | 0.0468      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.139      |
# |    explained_variance   | 0.304       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0104      |
# |    n_updates            | 4780        |
# |    policy_gradient_loss | -0.00128    |
# |    value_loss           | 0.0266      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4e+03     |
# |    ep_rew_mean          | 295         |
# | time/                   |             |
# |    fps                  | 629         |
# |    iterations           | 480         |
# |    time_elapsed         | 780         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.004832193 |
# |    clip_fraction        | 0.0311      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.132      |
# |    explained_variance   | 0.688       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0146      |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | -8.58e-05   |
# |    value_loss           | 0.0143      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.4e+03      |
# |    ep_rew_mean          | 295          |
# | time/                   |              |
# |    fps                  | 629          |
# |    iterations           | 481          |
# |    time_elapsed         | 782          |
# |    total_timesteps      | 492544       |
# | train/                  |              |
# |    approx_kl            | 0.0038073773 |
# |    clip_fraction        | 0.0357       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.129       |
# |    explained_variance   | 0.832        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00502     |
# |    n_updates            | 4800         |
# |    policy_gradient_loss | 0.000357     |
# |    value_loss           | 0.00923      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.41e+03    |
# |    ep_rew_mean          | 296         |
# | time/                   |             |
# |    fps                  | 629         |
# |    iterations           | 482         |
# |    time_elapsed         | 784         |
# |    total_timesteps      | 493568      |
# | train/                  |             |
# |    approx_kl            | 0.007917361 |
# |    clip_fraction        | 0.0508      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.135      |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00714    |
# |    n_updates            | 4810        |
# |    policy_gradient_loss | -0.00165    |
# |    value_loss           | 0.00688     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.41e+03  |
# |    ep_rew_mean          | 296       |
# | time/                   |           |
# |    fps                  | 629       |
# |    iterations           | 483       |
# |    time_elapsed         | 785       |
# |    total_timesteps      | 494592    |
# | train/                  |           |
# |    approx_kl            | 0.0021428 |
# |    clip_fraction        | 0.0345    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.117    |
# |    explained_variance   | 0.049     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.301     |
# |    n_updates            | 4820      |
# |    policy_gradient_loss | -0.00219  |
# |    value_loss           | 1.03      |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.41e+03     |
# |    ep_rew_mean          | 296          |
# | time/                   |              |
# |    fps                  | 629          |
# |    iterations           | 484          |
# |    time_elapsed         | 787          |
# |    total_timesteps      | 495616       |
# | train/                  |              |
# |    approx_kl            | 0.0074179247 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.124       |
# |    explained_variance   | -0.373       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00995      |
# |    n_updates            | 4830         |
# |    policy_gradient_loss | 0.000289     |
# |    value_loss           | 0.0272       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.41e+03    |
# |    ep_rew_mean          | 296         |
# | time/                   |             |
# |    fps                  | 629         |
# |    iterations           | 485         |
# |    time_elapsed         | 788         |
# |    total_timesteps      | 496640      |
# | train/                  |             |
# |    approx_kl            | 0.004607644 |
# |    clip_fraction        | 0.0343      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0967     |
# |    explained_variance   | 0.796       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00283    |
# |    n_updates            | 4840        |
# |    policy_gradient_loss | -0.00309    |
# |    value_loss           | 0.00844     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.41e+03    |
# |    ep_rew_mean          | 296         |
# | time/                   |             |
# |    fps                  | 629         |
# |    iterations           | 486         |
# |    time_elapsed         | 790         |
# |    total_timesteps      | 497664      |
# | train/                  |             |
# |    approx_kl            | 0.004869949 |
# |    clip_fraction        | 0.0205      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0904     |
# |    explained_variance   | 0.878       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00067     |
# |    n_updates            | 4850        |
# |    policy_gradient_loss | 0.000636    |
# |    value_loss           | 0.00685     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.41e+03    |
# |    ep_rew_mean          | 296         |
# | time/                   |             |
# |    fps                  | 629         |
# |    iterations           | 487         |
# |    time_elapsed         | 792         |
# |    total_timesteps      | 498688      |
# | train/                  |             |
# |    approx_kl            | 0.002173806 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0915     |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000462   |
# |    n_updates            | 4860        |
# |    policy_gradient_loss | 0.000851    |
# |    value_loss           | 0.0066      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.41e+03     |
# |    ep_rew_mean          | 296          |
# | time/                   |              |
# |    fps                  | 629          |
# |    iterations           | 488          |
# |    time_elapsed         | 793          |
# |    total_timesteps      | 499712       |
# | train/                  |              |
# |    approx_kl            | 0.0030885418 |
# |    clip_fraction        | 0.0294       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.105       |
# |    explained_variance   | 0.913        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00287      |
# |    n_updates            | 4870         |
# |    policy_gradient_loss | 0.000565     |
# |    value_loss           | 0.00572      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.41e+03    |
# |    ep_rew_mean          | 296         |
# | time/                   |             |
# |    fps                  | 629         |
# |    iterations           | 489         |
# |    time_elapsed         | 795         |
# |    total_timesteps      | 500736      |
# | train/                  |             |
# |    approx_kl            | 0.015057361 |
# |    clip_fraction        | 0.0349      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.11       |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0174     |
# |    n_updates            | 4880        |
# |    policy_gradient_loss | 0.000875    |
# |    value_loss           | 0.00566     |
# -----------------------------------------

# %%
gym.envs.registration.register(
    id='CustomFlappyBird-v1',
    entry_point='__main__:CustomFlappyBirdEnv_gap150',
    max_episode_steps=10000000,
)

# Environment erstellen und mit VecMonitor wrappen
env = make_vec_env("CustomFlappyBird-v1", n_envs=4, env_kwargs={'render_mode': 'rgb_array', 'use_lidar': False})

# %%
# Laden des gespeicherten Modells
model = PPO.load("../models/PPO_MLP_gap200_500k")

# Setzen der neuen Umgebung im Modell
model.set_env(env)

# Fortsetzung des Trainings bei 500000 Timestamps und weiter in das gleiche Log-File schreiben
model.set_logger(new_logger)
model.learn(total_timesteps=500000, reset_num_timesteps=False)

# Modell speichern
model.save("../models/PPO_MLP_gap150_500k")
# Out:
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.34e+03    |
# |    ep_rew_mean          | 287         |
# | time/                   |             |
# |    fps                  | 1356        |
# |    iterations           | 1           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 501760      |
# | train/                  |             |
# |    approx_kl            | 0.002674543 |
# |    clip_fraction        | 0.0336      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.141      |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00532    |
# |    n_updates            | 4890        |
# |    policy_gradient_loss | -0.000846   |
# |    value_loss           | 0.00509     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.33e+03      |
# |    ep_rew_mean          | 286           |
# | time/                   |               |
# |    fps                  | 753           |
# |    iterations           | 2             |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 502784        |
# | train/                  |               |
# |    approx_kl            | 0.00063102273 |
# |    clip_fraction        | 0.00957       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.167        |
# |    explained_variance   | -0.0253       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.81          |
# |    n_updates            | 4900          |
# |    policy_gradient_loss | -0.000614     |
# |    value_loss           | 5.44          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.32e+03     |
# |    ep_rew_mean          | 285          |
# | time/                   |              |
# |    fps                  | 665          |
# |    iterations           | 3            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 503808       |
# | train/                  |              |
# |    approx_kl            | 0.0022861464 |
# |    clip_fraction        | 0.0226       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.154       |
# |    explained_variance   | 0.205        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.49         |
# |    n_updates            | 4910         |
# |    policy_gradient_loss | -0.00239     |
# |    value_loss           | 5.23         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.32e+03    |
# |    ep_rew_mean          | 285         |
# | time/                   |             |
# |    fps                  | 626         |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 504832      |
# | train/                  |             |
# |    approx_kl            | 0.002266442 |
# |    clip_fraction        | 0.0304      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.14       |
# |    explained_variance   | 0.318       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.49        |
# |    n_updates            | 4920        |
# |    policy_gradient_loss | -0.00301    |
# |    value_loss           | 2.22        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.32e+03     |
# |    ep_rew_mean          | 285          |
# | time/                   |              |
# |    fps                  | 603          |
# |    iterations           | 5            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 505856       |
# | train/                  |              |
# |    approx_kl            | 0.0019276182 |
# |    clip_fraction        | 0.0402       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.124       |
# |    explained_variance   | 0.0813       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0385       |
# |    n_updates            | 4930         |
# |    policy_gradient_loss | -0.00329     |
# |    value_loss           | 0.597        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.32e+03     |
# |    ep_rew_mean          | 285          |
# | time/                   |              |
# |    fps                  | 591          |
# |    iterations           | 6            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 506880       |
# | train/                  |              |
# |    approx_kl            | 0.0033231438 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.136       |
# |    explained_variance   | 0.35         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.279        |
# |    n_updates            | 4940         |
# |    policy_gradient_loss | -0.00135     |
# |    value_loss           | 1.3          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.33e+03     |
# |    ep_rew_mean          | 286          |
# | time/                   |              |
# |    fps                  | 588          |
# |    iterations           | 7            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 507904       |
# | train/                  |              |
# |    approx_kl            | 0.0028627533 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.123       |
# |    explained_variance   | 0.297        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.31         |
# |    n_updates            | 4950         |
# |    policy_gradient_loss | -0.00266     |
# |    value_loss           | 0.425        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.32e+03     |
# |    ep_rew_mean          | 286          |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 8            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 508928       |
# | train/                  |              |
# |    approx_kl            | 0.0014157123 |
# |    clip_fraction        | 0.0261       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.133       |
# |    explained_variance   | 0.202        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.4          |
# |    n_updates            | 4960         |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 2.74         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.31e+03     |
# |    ep_rew_mean          | 284          |
# | time/                   |              |
# |    fps                  | 579          |
# |    iterations           | 9            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 509952       |
# | train/                  |              |
# |    approx_kl            | 0.0017480389 |
# |    clip_fraction        | 0.0299       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0949      |
# |    explained_variance   | 0.178        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.644        |
# |    n_updates            | 4970         |
# |    policy_gradient_loss | -0.00228     |
# |    value_loss           | 1.71         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.31e+03     |
# |    ep_rew_mean          | 284          |
# | time/                   |              |
# |    fps                  | 577          |
# |    iterations           | 10           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 510976       |
# | train/                  |              |
# |    approx_kl            | 0.0012770742 |
# |    clip_fraction        | 0.0198       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0942      |
# |    explained_variance   | 0.47         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.146        |
# |    n_updates            | 4980         |
# |    policy_gradient_loss | -0.00269     |
# |    value_loss           | 0.8          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.3e+03    |
# |    ep_rew_mean          | 283        |
# | time/                   |            |
# |    fps                  | 575        |
# |    iterations           | 11         |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 512000     |
# | train/                  |            |
# |    approx_kl            | 0.02290104 |
# |    clip_fraction        | 0.0632     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.139     |
# |    explained_variance   | 0.134      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00224    |
# |    n_updates            | 4990       |
# |    policy_gradient_loss | 0.00346    |
# |    value_loss           | 0.0805     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.3e+03      |
# |    ep_rew_mean          | 283          |
# | time/                   |              |
# |    fps                  | 573          |
# |    iterations           | 12           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 513024       |
# | train/                  |              |
# |    approx_kl            | 0.0032984414 |
# |    clip_fraction        | 0.0345       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.127       |
# |    explained_variance   | 0.0204       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.787        |
# |    n_updates            | 5000         |
# |    policy_gradient_loss | 0.000507     |
# |    value_loss           | 2.02         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.31e+03     |
# |    ep_rew_mean          | 284          |
# | time/                   |              |
# |    fps                  | 572          |
# |    iterations           | 13           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 514048       |
# | train/                  |              |
# |    approx_kl            | 0.0050791893 |
# |    clip_fraction        | 0.0297       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.13        |
# |    explained_variance   | 0.181        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.52         |
# |    n_updates            | 5010         |
# |    policy_gradient_loss | -0.00211     |
# |    value_loss           | 1.01         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.28e+03   |
# |    ep_rew_mean          | 281        |
# | time/                   |            |
# |    fps                  | 572        |
# |    iterations           | 14         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 515072     |
# | train/                  |            |
# |    approx_kl            | 0.00231196 |
# |    clip_fraction        | 0.0389     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.136     |
# |    explained_variance   | 0.108      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.628      |
# |    n_updates            | 5020       |
# |    policy_gradient_loss | -0.00236   |
# |    value_loss           | 2.73       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.27e+03    |
# |    ep_rew_mean          | 279         |
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 15          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 516096      |
# | train/                  |             |
# |    approx_kl            | 0.005733444 |
# |    clip_fraction        | 0.0478      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.124      |
# |    explained_variance   | 0.194       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.28        |
# |    n_updates            | 5030        |
# |    policy_gradient_loss | -0.00165    |
# |    value_loss           | 1.55        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.27e+03     |
# |    ep_rew_mean          | 279          |
# | time/                   |              |
# |    fps                  | 569          |
# |    iterations           | 16           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 517120       |
# | train/                  |              |
# |    approx_kl            | 0.0041842177 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.115       |
# |    explained_variance   | 0.144        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.359        |
# |    n_updates            | 5040         |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 2.03         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.28e+03   |
# |    ep_rew_mean          | 280        |
# | time/                   |            |
# |    fps                  | 568        |
# |    iterations           | 17         |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 518144     |
# | train/                  |            |
# |    approx_kl            | 0.03509375 |
# |    clip_fraction        | 0.0848     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.155     |
# |    explained_variance   | 0.136      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00977    |
# |    n_updates            | 5050       |
# |    policy_gradient_loss | 0.00314    |
# |    value_loss           | 0.082      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.27e+03     |
# |    ep_rew_mean          | 280          |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 18           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 519168       |
# | train/                  |              |
# |    approx_kl            | 0.0059227375 |
# |    clip_fraction        | 0.0574       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.169       |
# |    explained_variance   | -0.00916     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.85         |
# |    n_updates            | 5060         |
# |    policy_gradient_loss | -0.000141    |
# |    value_loss           | 3            |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.27e+03     |
# |    ep_rew_mean          | 279          |
# | time/                   |              |
# |    fps                  | 566          |
# |    iterations           | 19           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 520192       |
# | train/                  |              |
# |    approx_kl            | 0.0019487287 |
# |    clip_fraction        | 0.0338       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.14        |
# |    explained_variance   | 0.344        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.31         |
# |    n_updates            | 5070         |
# |    policy_gradient_loss | -0.00227     |
# |    value_loss           | 2.29         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.26e+03     |
# |    ep_rew_mean          | 278          |
# | time/                   |              |
# |    fps                  | 566          |
# |    iterations           | 20           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 521216       |
# | train/                  |              |
# |    approx_kl            | 0.0042049633 |
# |    clip_fraction        | 0.0691       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.126       |
# |    explained_variance   | -0.137       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.932        |
# |    n_updates            | 5080         |
# |    policy_gradient_loss | -0.00524     |
# |    value_loss           | 1.31         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.27e+03     |
# |    ep_rew_mean          | 279          |
# | time/                   |              |
# |    fps                  | 565          |
# |    iterations           | 21           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 522240       |
# | train/                  |              |
# |    approx_kl            | 0.0043880707 |
# |    clip_fraction        | 0.0608       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.157       |
# |    explained_variance   | 0.271        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.558        |
# |    n_updates            | 5090         |
# |    policy_gradient_loss | -0.00198     |
# |    value_loss           | 1.52         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.26e+03     |
# |    ep_rew_mean          | 278          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 22           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 523264       |
# | train/                  |              |
# |    approx_kl            | 0.0008447828 |
# |    clip_fraction        | 0.0558       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.137       |
# |    explained_variance   | 0.138        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.158        |
# |    n_updates            | 5100         |
# |    policy_gradient_loss | -0.000594    |
# |    value_loss           | 0.768        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.26e+03    |
# |    ep_rew_mean          | 278         |
# | time/                   |             |
# |    fps                  | 563         |
# |    iterations           | 23          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 524288      |
# | train/                  |             |
# |    approx_kl            | 0.001511095 |
# |    clip_fraction        | 0.0292      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.151      |
# |    explained_variance   | 0.0354      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.31        |
# |    n_updates            | 5110        |
# |    policy_gradient_loss | 0.00211     |
# |    value_loss           | 1.05        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.21e+03     |
# |    ep_rew_mean          | 272          |
# | time/                   |              |
# |    fps                  | 563          |
# |    iterations           | 24           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 525312       |
# | train/                  |              |
# |    approx_kl            | 0.0038909037 |
# |    clip_fraction        | 0.0638       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.166       |
# |    explained_variance   | 0.478        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0037       |
# |    n_updates            | 5120         |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 0.0254       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.19e+03    |
# |    ep_rew_mean          | 269         |
# | time/                   |             |
# |    fps                  | 562         |
# |    iterations           | 25          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 526336      |
# | train/                  |             |
# |    approx_kl            | 0.001410926 |
# |    clip_fraction        | 0.0255      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.129      |
# |    explained_variance   | 0.0533      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3         |
# |    n_updates            | 5130        |
# |    policy_gradient_loss | -0.00102    |
# |    value_loss           | 2.82        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.17e+03     |
# |    ep_rew_mean          | 267          |
# | time/                   |              |
# |    fps                  | 562          |
# |    iterations           | 26           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 527360       |
# | train/                  |              |
# |    approx_kl            | 0.0039799064 |
# |    clip_fraction        | 0.0421       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.13        |
# |    explained_variance   | 0.302        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.24         |
# |    n_updates            | 5140         |
# |    policy_gradient_loss | -0.0022      |
# |    value_loss           | 1.63         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.17e+03     |
# |    ep_rew_mean          | 267          |
# | time/                   |              |
# |    fps                  | 562          |
# |    iterations           | 27           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 528384       |
# | train/                  |              |
# |    approx_kl            | 0.0014109721 |
# |    clip_fraction        | 0.0249       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.138       |
# |    explained_variance   | -0.172       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.728        |
# |    n_updates            | 5150         |
# |    policy_gradient_loss | -0.000415    |
# |    value_loss           | 1.14         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.15e+03     |
# |    ep_rew_mean          | 264          |
# | time/                   |              |
# |    fps                  | 561          |
# |    iterations           | 28           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 529408       |
# | train/                  |              |
# |    approx_kl            | 0.0031195744 |
# |    clip_fraction        | 0.0509       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.132       |
# |    explained_variance   | 0.128        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.688        |
# |    n_updates            | 5160         |
# |    policy_gradient_loss | -0.00336     |
# |    value_loss           | 2.08         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.15e+03     |
# |    ep_rew_mean          | 264          |
# | time/                   |              |
# |    fps                  | 561          |
# |    iterations           | 29           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 530432       |
# | train/                  |              |
# |    approx_kl            | 0.0022380664 |
# |    clip_fraction        | 0.0388       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.123       |
# |    explained_variance   | 0.524        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.204        |
# |    n_updates            | 5170         |
# |    policy_gradient_loss | -0.00289     |
# |    value_loss           | 0.719        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.06e+03    |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 561         |
# |    iterations           | 30          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 531456      |
# | train/                  |             |
# |    approx_kl            | 0.003724486 |
# |    clip_fraction        | 0.0524      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.134      |
# |    explained_variance   | 0.193       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.023       |
# |    n_updates            | 5180        |
# |    policy_gradient_loss | -0.000204   |
# |    value_loss           | 0.0323      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.05e+03     |
# |    ep_rew_mean          | 252          |
# | time/                   |              |
# |    fps                  | 563          |
# |    iterations           | 31           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 532480       |
# | train/                  |              |
# |    approx_kl            | 0.0021642908 |
# |    clip_fraction        | 0.0346       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.117       |
# |    explained_variance   | 0.0484       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.948        |
# |    n_updates            | 5190         |
# |    policy_gradient_loss | -0.000477    |
# |    value_loss           | 2.48         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.05e+03     |
# |    ep_rew_mean          | 252          |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 32           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 533504       |
# | train/                  |              |
# |    approx_kl            | 0.0043200664 |
# |    clip_fraction        | 0.0325       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.126       |
# |    explained_variance   | 0.321        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.19         |
# |    n_updates            | 5200         |
# |    policy_gradient_loss | 5.25e-05     |
# |    value_loss           | 1.81         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.05e+03     |
# |    ep_rew_mean          | 252          |
# | time/                   |              |
# |    fps                  | 566          |
# |    iterations           | 33           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 534528       |
# | train/                  |              |
# |    approx_kl            | 0.0010552927 |
# |    clip_fraction        | 0.0314       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.126       |
# |    explained_variance   | -0.753       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0254       |
# |    n_updates            | 5210         |
# |    policy_gradient_loss | 7e-05        |
# |    value_loss           | 0.0623       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.04e+03      |
# |    ep_rew_mean          | 251           |
# | time/                   |               |
# |    fps                  | 568           |
# |    iterations           | 34            |
# |    time_elapsed         | 61            |
# |    total_timesteps      | 535552        |
# | train/                  |               |
# |    approx_kl            | 0.00059941434 |
# |    clip_fraction        | 0.0281        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.108        |
# |    explained_variance   | 0.482         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00876       |
# |    n_updates            | 5220          |
# |    policy_gradient_loss | 0.000204      |
# |    value_loss           | 0.0196        |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.97e+03   |
# |    ep_rew_mean          | 242        |
# | time/                   |            |
# |    fps                  | 569        |
# |    iterations           | 35         |
# |    time_elapsed         | 62         |
# |    total_timesteps      | 536576     |
# | train/                  |            |
# |    approx_kl            | 0.00437929 |
# |    clip_fraction        | 0.0426     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.148     |
# |    explained_variance   | 0.197      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.473      |
# |    n_updates            | 5230       |
# |    policy_gradient_loss | -0.00134   |
# |    value_loss           | 1.67       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.97e+03   |
# |    ep_rew_mean          | 242        |
# | time/                   |            |
# |    fps                  | 570        |
# |    iterations           | 36         |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 537600     |
# | train/                  |            |
# |    approx_kl            | 0.00430391 |
# |    clip_fraction        | 0.0361     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.12      |
# |    explained_variance   | -0.147     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.38       |
# |    n_updates            | 5240       |
# |    policy_gradient_loss | 0.000606   |
# |    value_loss           | 1.18       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.92e+03    |
# |    ep_rew_mean          | 236         |
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 37          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 538624      |
# | train/                  |             |
# |    approx_kl            | 0.003054667 |
# |    clip_fraction        | 0.0313      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.119      |
# |    explained_variance   | 0.348       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0152      |
# |    n_updates            | 5250        |
# |    policy_gradient_loss | 0.00127     |
# |    value_loss           | 0.0405      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.88e+03     |
# |    ep_rew_mean          | 231          |
# | time/                   |              |
# |    fps                  | 572          |
# |    iterations           | 38           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 539648       |
# | train/                  |              |
# |    approx_kl            | 0.0042497115 |
# |    clip_fraction        | 0.0435       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.13        |
# |    explained_variance   | 0.0796       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.75         |
# |    n_updates            | 5260         |
# |    policy_gradient_loss | -0.00405     |
# |    value_loss           | 2.86         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.84e+03    |
# |    ep_rew_mean          | 226         |
# | time/                   |             |
# |    fps                  | 573         |
# |    iterations           | 39          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 540672      |
# | train/                  |             |
# |    approx_kl            | 0.008964189 |
# |    clip_fraction        | 0.0457      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.136      |
# |    explained_variance   | 0.114       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.6         |
# |    n_updates            | 5270        |
# |    policy_gradient_loss | 0.00119     |
# |    value_loss           | 1.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | 211         |
# | time/                   |             |
# |    fps                  | 573         |
# |    iterations           | 40          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 541696      |
# | train/                  |             |
# |    approx_kl            | 0.010054519 |
# |    clip_fraction        | 0.0626      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.164      |
# |    explained_variance   | 0.191       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.94        |
# |    n_updates            | 5280        |
# |    policy_gradient_loss | -0.00216    |
# |    value_loss           | 0.937       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.39e+03     |
# |    ep_rew_mean          | 171          |
# | time/                   |              |
# |    fps                  | 574          |
# |    iterations           | 41           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 542720       |
# | train/                  |              |
# |    approx_kl            | 0.0038034837 |
# |    clip_fraction        | 0.0363       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.127       |
# |    explained_variance   | 0.454        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.795        |
# |    n_updates            | 5290         |
# |    policy_gradient_loss | -0.00253     |
# |    value_loss           | 1.53         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.39e+03      |
# |    ep_rew_mean          | 171           |
# | time/                   |               |
# |    fps                  | 575           |
# |    iterations           | 42            |
# |    time_elapsed         | 74            |
# |    total_timesteps      | 543744        |
# | train/                  |               |
# |    approx_kl            | 0.00093677815 |
# |    clip_fraction        | 0.0184        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.124        |
# |    explained_variance   | 0.289         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.22          |
# |    n_updates            | 5300          |
# |    policy_gradient_loss | -0.00107      |
# |    value_loss           | 2.28          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.32e+03     |
# |    ep_rew_mean          | 162          |
# | time/                   |              |
# |    fps                  | 575          |
# |    iterations           | 43           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 544768       |
# | train/                  |              |
# |    approx_kl            | 0.0032712577 |
# |    clip_fraction        | 0.0243       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.137       |
# |    explained_variance   | -0.765       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.099        |
# |    n_updates            | 5310         |
# |    policy_gradient_loss | 8.42e-05     |
# |    value_loss           | 0.194        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.32e+03     |
# |    ep_rew_mean          | 162          |
# | time/                   |              |
# |    fps                  | 576          |
# |    iterations           | 44           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 545792       |
# | train/                  |              |
# |    approx_kl            | 0.0035166456 |
# |    clip_fraction        | 0.0387       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.138       |
# |    explained_variance   | 0.453        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.595        |
# |    n_updates            | 5320         |
# |    policy_gradient_loss | 0.00121      |
# |    value_loss           | 0.786        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.15e+03   |
# |    ep_rew_mean          | 140        |
# | time/                   |            |
# |    fps                  | 576        |
# |    iterations           | 45         |
# |    time_elapsed         | 79         |
# |    total_timesteps      | 546816     |
# | train/                  |            |
# |    approx_kl            | 0.00428927 |
# |    clip_fraction        | 0.0453     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.136     |
# |    explained_variance   | -0.18      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0255     |
# |    n_updates            | 5330       |
# |    policy_gradient_loss | 0.000492   |
# |    value_loss           | 0.101      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.15e+03     |
# |    ep_rew_mean          | 140          |
# | time/                   |              |
# |    fps                  | 576          |
# |    iterations           | 46           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 547840       |
# | train/                  |              |
# |    approx_kl            | 0.0017657228 |
# |    clip_fraction        | 0.0367       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.121       |
# |    explained_variance   | 0.0577       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.395        |
# |    n_updates            | 5340         |
# |    policy_gradient_loss | -0.0023      |
# |    value_loss           | 1.87         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.13e+03     |
# |    ep_rew_mean          | 138          |
# | time/                   |              |
# |    fps                  | 576          |
# |    iterations           | 47           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 548864       |
# | train/                  |              |
# |    approx_kl            | 0.0014192627 |
# |    clip_fraction        | 0.0294       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.117       |
# |    explained_variance   | -0.0498      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0381       |
# |    n_updates            | 5350         |
# |    policy_gradient_loss | -0.000846    |
# |    value_loss           | 0.105        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.08e+03     |
# |    ep_rew_mean          | 132          |
# | time/                   |              |
# |    fps                  | 576          |
# |    iterations           | 48           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 549888       |
# | train/                  |              |
# |    approx_kl            | 0.0041036652 |
# |    clip_fraction        | 0.0452       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.15        |
# |    explained_variance   | -4.91e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.501        |
# |    n_updates            | 5360         |
# |    policy_gradient_loss | -0.00268     |
# |    value_loss           | 1.18         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 965         |
# |    ep_rew_mean          | 117         |
# | time/                   |             |
# |    fps                  | 577         |
# |    iterations           | 49          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 550912      |
# | train/                  |             |
# |    approx_kl            | 0.009676501 |
# |    clip_fraction        | 0.0448      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.15       |
# |    explained_variance   | 0.134       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.22        |
# |    n_updates            | 5370        |
# |    policy_gradient_loss | -0.000305   |
# |    value_loss           | 0.947       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 117          |
# | time/                   |              |
# |    fps                  | 577          |
# |    iterations           | 50           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 551936       |
# | train/                  |              |
# |    approx_kl            | 0.0028303221 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.135       |
# |    explained_variance   | 0.135        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.6          |
# |    n_updates            | 5380         |
# |    policy_gradient_loss | -0.00396     |
# |    value_loss           | 3.89         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 940          |
# |    ep_rew_mean          | 114          |
# | time/                   |              |
# |    fps                  | 578          |
# |    iterations           | 51           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 552960       |
# | train/                  |              |
# |    approx_kl            | 0.0035656593 |
# |    clip_fraction        | 0.0349       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.117       |
# |    explained_variance   | 0.131        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0511       |
# |    n_updates            | 5390         |
# |    policy_gradient_loss | -0.00201     |
# |    value_loss           | 1.17         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 945          |
# |    ep_rew_mean          | 115          |
# | time/                   |              |
# |    fps                  | 578          |
# |    iterations           | 52           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 553984       |
# | train/                  |              |
# |    approx_kl            | 0.0021622835 |
# |    clip_fraction        | 0.0374       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.119       |
# |    explained_variance   | 0.331        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.793        |
# |    n_updates            | 5400         |
# |    policy_gradient_loss | 0.000368     |
# |    value_loss           | 1.8          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 945         |
# |    ep_rew_mean          | 115         |
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 53          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 555008      |
# | train/                  |             |
# |    approx_kl            | 0.002823528 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.107      |
# |    explained_variance   | 0.206       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.385       |
# |    n_updates            | 5410        |
# |    policy_gradient_loss | -0.00308    |
# |    value_loss           | 0.935       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 945          |
# |    ep_rew_mean          | 115          |
# | time/                   |              |
# |    fps                  | 580          |
# |    iterations           | 54           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 556032       |
# | train/                  |              |
# |    approx_kl            | 0.0019247404 |
# |    clip_fraction        | 0.0297       |
# |    clip_range           | 0.2          |
# ...
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 472          |
# |    time_elapsed         | 799          |
# |    total_timesteps      | 984064       |
# | train/                  |              |
# |    approx_kl            | 0.0029814676 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0996      |
# |    explained_variance   | 0.71         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00493      |
# |    n_updates            | 9600         |
# |    policy_gradient_loss | 0.00037      |
# |    value_loss           | 0.0113       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.06e+03    |
# |    ep_rew_mean          | 129         |
# | time/                   |             |
# |    fps                  | 604         |
# |    iterations           | 473         |
# |    time_elapsed         | 801         |
# |    total_timesteps      | 985088      |
# | train/                  |             |
# |    approx_kl            | 0.006463616 |
# |    clip_fraction        | 0.031       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.124      |
# |    explained_variance   | 0.107       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0798      |
# |    n_updates            | 9610        |
# |    policy_gradient_loss | -0.00161    |
# |    value_loss           | 1.3         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.06e+03     |
# |    ep_rew_mean          | 129          |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 474          |
# |    time_elapsed         | 803          |
# |    total_timesteps      | 986112       |
# | train/                  |              |
# |    approx_kl            | 0.0019365642 |
# |    clip_fraction        | 0.0194       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.12        |
# |    explained_variance   | 0.0448       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0455       |
# |    n_updates            | 9620         |
# |    policy_gradient_loss | -0.0013      |
# |    value_loss           | 1.16         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.06e+03     |
# |    ep_rew_mean          | 129          |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 475          |
# |    time_elapsed         | 804          |
# |    total_timesteps      | 987136       |
# | train/                  |              |
# |    approx_kl            | 0.0037017916 |
# |    clip_fraction        | 0.0416       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.113       |
# |    explained_variance   | -0.0602      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00497      |
# |    n_updates            | 9630         |
# |    policy_gradient_loss | -0.0016      |
# |    value_loss           | 0.0394       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.09e+03     |
# |    ep_rew_mean          | 133          |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 476          |
# |    time_elapsed         | 806          |
# |    total_timesteps      | 988160       |
# | train/                  |              |
# |    approx_kl            | 0.0016804027 |
# |    clip_fraction        | 0.0254       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.12        |
# |    explained_variance   | 0.67         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00158      |
# |    n_updates            | 9640         |
# |    policy_gradient_loss | 0.00172      |
# |    value_loss           | 0.0145       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.09e+03     |
# |    ep_rew_mean          | 133          |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 477          |
# |    time_elapsed         | 808          |
# |    total_timesteps      | 989184       |
# | train/                  |              |
# |    approx_kl            | 0.0033128476 |
# |    clip_fraction        | 0.0473       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.138       |
# |    explained_variance   | 0.0271       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.063        |
# |    n_updates            | 9650         |
# |    policy_gradient_loss | -0.00316     |
# |    value_loss           | 0.989        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.14e+03     |
# |    ep_rew_mean          | 139          |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 478          |
# |    time_elapsed         | 810          |
# |    total_timesteps      | 990208       |
# | train/                  |              |
# |    approx_kl            | 0.0011812252 |
# |    clip_fraction        | 0.0307       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.131       |
# |    explained_variance   | -0.0493      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0447       |
# |    n_updates            | 9660         |
# |    policy_gradient_loss | 0.000961     |
# |    value_loss           | 0.0386       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.12e+03    |
# |    ep_rew_mean          | 137         |
# | time/                   |             |
# |    fps                  | 604         |
# |    iterations           | 479         |
# |    time_elapsed         | 811         |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.004520969 |
# |    clip_fraction        | 0.0446      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.126      |
# |    explained_variance   | 0.0892      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.674       |
# |    n_updates            | 9670        |
# |    policy_gradient_loss | -0.00382    |
# |    value_loss           | 1.24        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.12e+03     |
# |    ep_rew_mean          | 137          |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 480          |
# |    time_elapsed         | 813          |
# |    total_timesteps      | 992256       |
# | train/                  |              |
# |    approx_kl            | 0.0018183716 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.116       |
# |    explained_variance   | -0.0235      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.314        |
# |    n_updates            | 9680         |
# |    policy_gradient_loss | -0.000293    |
# |    value_loss           | 1.14         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.06e+03    |
# |    ep_rew_mean          | 129         |
# | time/                   |             |
# |    fps                  | 604         |
# |    iterations           | 481         |
# |    time_elapsed         | 815         |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.000898631 |
# |    clip_fraction        | 0.0248      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0983     |
# |    explained_variance   | -0.253      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00934     |
# |    n_updates            | 9690        |
# |    policy_gradient_loss | 0.000713    |
# |    value_loss           | 0.0434      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.06e+03     |
# |    ep_rew_mean          | 129          |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 482          |
# |    time_elapsed         | 816          |
# |    total_timesteps      | 994304       |
# | train/                  |              |
# |    approx_kl            | 0.0012674916 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.103       |
# |    explained_variance   | 0.223        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.753        |
# |    n_updates            | 9700         |
# |    policy_gradient_loss | -0.000462    |
# |    value_loss           | 0.939        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.08e+03     |
# |    ep_rew_mean          | 131          |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 483          |
# |    time_elapsed         | 818          |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0034912825 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0915      |
# |    explained_variance   | 0.493        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00114     |
# |    n_updates            | 9710         |
# |    policy_gradient_loss | -0.00185     |
# |    value_loss           | 0.019        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.08e+03     |
# |    ep_rew_mean          | 131          |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 484          |
# |    time_elapsed         | 820          |
# |    total_timesteps      | 996352       |
# | train/                  |              |
# |    approx_kl            | 0.0014442902 |
# |    clip_fraction        | 0.0269       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.108       |
# |    explained_variance   | 0.0987       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.778        |
# |    n_updates            | 9720         |
# |    policy_gradient_loss | -0.000634    |
# |    value_loss           | 0.782        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.08e+03     |
# |    ep_rew_mean          | 131          |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 485          |
# |    time_elapsed         | 821          |
# |    total_timesteps      | 997376       |
# | train/                  |              |
# |    approx_kl            | 0.0037273522 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.114       |
# |    explained_variance   | 0.579        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00835      |
# |    n_updates            | 9730         |
# |    policy_gradient_loss | 0.00143      |
# |    value_loss           | 0.0179       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.08e+03    |
# |    ep_rew_mean          | 131         |
# | time/                   |             |
# |    fps                  | 604         |
# |    iterations           | 486         |
# |    time_elapsed         | 823         |
# |    total_timesteps      | 998400      |
# | train/                  |             |
# |    approx_kl            | 0.001543842 |
# |    clip_fraction        | 0.0308      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.129      |
# |    explained_variance   | 0.608       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00807    |
# |    n_updates            | 9740        |
# |    policy_gradient_loss | -0.000475   |
# |    value_loss           | 0.0115      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.08e+03    |
# |    ep_rew_mean          | 132         |
# | time/                   |             |
# |    fps                  | 604         |
# |    iterations           | 487         |
# |    time_elapsed         | 825         |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.008705335 |
# |    clip_fraction        | 0.0356      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.111      |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00583    |
# |    n_updates            | 9750        |
# |    policy_gradient_loss | 0.00128     |
# |    value_loss           | 0.00585     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.08e+03      |
# |    ep_rew_mean          | 132           |
# | time/                   |               |
# |    fps                  | 604           |
# |    iterations           | 488           |
# |    time_elapsed         | 826           |
# |    total_timesteps      | 1000448       |
# | train/                  |               |
# |    approx_kl            | 0.00056955114 |
# |    clip_fraction        | 0.0206        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.112        |
# |    explained_variance   | 0.0853        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.063         |
# |    n_updates            | 9760          |
# |    policy_gradient_loss | 0.000699      |
# |    value_loss           | 0.839         |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.08e+03    |
# |    ep_rew_mean          | 132         |
# | time/                   |             |
# |    fps                  | 604         |
# |    iterations           | 489         |
# |    time_elapsed         | 828         |
# |    total_timesteps      | 1001472     |
# | train/                  |             |
# |    approx_kl            | 0.003933077 |
# |    clip_fraction        | 0.0442      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.101      |
# |    explained_variance   | 0.237       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.432       |
# |    n_updates            | 9770        |
# |    policy_gradient_loss | -0.00302    |
# |    value_loss           | 0.435       |
# -----------------------------------------

# %%
gym.envs.registration.register(
    id='CustomFlappyBird-v2',
    entry_point='__main__:CustomFlappyBirdEnv_gap125',
    max_episode_steps=10000000,
)

# Environment erstellen und mit VecMonitor wrappen
env = make_vec_env("CustomFlappyBird-v2", n_envs=4, env_kwargs={'render_mode': 'rgb_array', 'use_lidar': False})

# %%
# Laden des gespeicherten Modells
model = PPO.load("../models/PPO_MLP_gap150_500k")

# Setzen der neuen Umgebung im Modell
model.set_env(env)

# Fortsetzung des Trainings bei 500000 Timestamps und weiter in das gleiche Log-File schreiben
model.set_logger(new_logger)
model.learn(total_timesteps=500000, reset_num_timesteps=False)

# Modell speichern
model.save("../models/PPO_MLP_gap125_500k")
# Out:
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.05e+03     |
# |    ep_rew_mean          | 128          |
# | time/                   |              |
# |    fps                  | 1362         |
# |    iterations           | 1            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 1002496      |
# | train/                  |              |
# |    approx_kl            | 0.0010707278 |
# |    clip_fraction        | 0.0236       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.117       |
# |    explained_variance   | -0.144       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0255       |
# |    n_updates            | 9780         |
# |    policy_gradient_loss | 2.4e-05      |
# |    value_loss           | 0.108        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 954           |
# |    ep_rew_mean          | 116           |
# | time/                   |               |
# |    fps                  | 744           |
# |    iterations           | 2             |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 1003520       |
# | train/                  |               |
# |    approx_kl            | 0.00020364515 |
# |    clip_fraction        | 0.00859       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0907       |
# |    explained_variance   | -0.00351      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.1           |
# |    n_updates            | 9790          |
# |    policy_gradient_loss | -9.26e-05     |
# |    value_loss           | 1.56          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 949          |
# |    ep_rew_mean          | 115          |
# | time/                   |              |
# |    fps                  | 654          |
# |    iterations           | 3            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 1004544      |
# | train/                  |              |
# |    approx_kl            | 0.0017916972 |
# |    clip_fraction        | 0.0197       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.112       |
# |    explained_variance   | -0.00636     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.44         |
# |    n_updates            | 9800         |
# |    policy_gradient_loss | -0.00133     |
# |    value_loss           | 6.7          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 905          |
# |    ep_rew_mean          | 110          |
# | time/                   |              |
# |    fps                  | 621          |
# |    iterations           | 4            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 1005568      |
# | train/                  |              |
# |    approx_kl            | 0.0014047388 |
# |    clip_fraction        | 0.0245       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.105       |
# |    explained_variance   | 0.0584       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.195        |
# |    n_updates            | 9810         |
# |    policy_gradient_loss | -0.00127     |
# |    value_loss           | 1.34         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 860          |
# |    ep_rew_mean          | 104          |
# | time/                   |              |
# |    fps                  | 602          |
# |    iterations           | 5            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 1006592      |
# | train/                  |              |
# |    approx_kl            | 0.0022503834 |
# |    clip_fraction        | 0.0249       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.107       |
# |    explained_variance   | 0.335        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.29         |
# |    n_updates            | 9820         |
# |    policy_gradient_loss | -0.000138    |
# |    value_loss           | 2.75         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 841          |
# |    ep_rew_mean          | 102          |
# | time/                   |              |
# |    fps                  | 593          |
# |    iterations           | 6            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 1007616      |
# | train/                  |              |
# |    approx_kl            | 0.0054914593 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.122       |
# |    explained_variance   | 0.212        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.3          |
# |    n_updates            | 9830         |
# |    policy_gradient_loss | -0.00443     |
# |    value_loss           | 3.55         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 836          |
# |    ep_rew_mean          | 101          |
# | time/                   |              |
# |    fps                  | 589          |
# |    iterations           | 7            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 1008640      |
# | train/                  |              |
# |    approx_kl            | 0.0017478261 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0946      |
# |    explained_variance   | 0.359        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.834        |
# |    n_updates            | 9840         |
# |    policy_gradient_loss | -3.16e-05    |
# |    value_loss           | 1.99         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 805          |
# |    ep_rew_mean          | 97.5         |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 8            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 1009664      |
# | train/                  |              |
# |    approx_kl            | 0.0025550807 |
# |    clip_fraction        | 0.0374       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0836      |
# |    explained_variance   | 0.319        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36         |
# |    n_updates            | 9850         |
# |    policy_gradient_loss | -0.00321     |
# |    value_loss           | 1.1          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 815          |
# |    ep_rew_mean          | 98.7         |
# | time/                   |              |
# |    fps                  | 579          |
# |    iterations           | 9            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 1010688      |
# | train/                  |              |
# |    approx_kl            | 0.0031358083 |
# |    clip_fraction        | 0.0343       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0951      |
# |    explained_variance   | 0.424        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.21         |
# |    n_updates            | 9860         |
# |    policy_gradient_loss | -0.00236     |
# |    value_loss           | 2.37         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 816         |
# |    ep_rew_mean          | 98.8        |
# | time/                   |             |
# |    fps                  | 575         |
# |    iterations           | 10          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 1011712     |
# | train/                  |             |
# |    approx_kl            | 0.001562018 |
# |    clip_fraction        | 0.019       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0914     |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.782       |
# |    n_updates            | 9870        |
# |    policy_gradient_loss | -0.00164    |
# |    value_loss           | 2.4         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 816         |
# |    ep_rew_mean          | 98.9        |
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 11          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 1012736     |
# | train/                  |             |
# |    approx_kl            | 0.002453168 |
# |    clip_fraction        | 0.028       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0799     |
# |    explained_variance   | 0.687       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.28        |
# |    n_updates            | 9880        |
# |    policy_gradient_loss | -0.0018     |
# |    value_loss           | 0.664       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 806          |
# |    ep_rew_mean          | 97.7         |
# | time/                   |              |
# |    fps                  | 570          |
# |    iterations           | 12           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 1013760      |
# | train/                  |              |
# |    approx_kl            | 0.0026301197 |
# |    clip_fraction        | 0.0337       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0985      |
# |    explained_variance   | -0.11        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0983       |
# |    n_updates            | 9890         |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 1.01         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 782          |
# |    ep_rew_mean          | 94.7         |
# | time/                   |              |
# |    fps                  | 568          |
# |    iterations           | 13           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 1014784      |
# | train/                  |              |
# |    approx_kl            | 0.0012578245 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.1         |
# |    explained_variance   | 0.271        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.862        |
# |    n_updates            | 9900         |
# |    policy_gradient_loss | -0.000491    |
# |    value_loss           | 1.68         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 761          |
# |    ep_rew_mean          | 92.1         |
# | time/                   |              |
# |    fps                  | 567          |
# |    iterations           | 14           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 1015808      |
# | train/                  |              |
# |    approx_kl            | 0.0013678547 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0956      |
# |    explained_variance   | 0.224        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.63         |
# |    n_updates            | 9910         |
# |    policy_gradient_loss | -0.00165     |
# |    value_loss           | 3.4          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 777          |
# |    ep_rew_mean          | 94.1         |
# | time/                   |              |
# |    fps                  | 566          |
# |    iterations           | 15           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 1016832      |
# | train/                  |              |
# |    approx_kl            | 0.0011860423 |
# |    clip_fraction        | 0.0227       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.085       |
# |    explained_variance   | 0.739        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.415        |
# |    n_updates            | 9920         |
# |    policy_gradient_loss | 0.00047      |
# |    value_loss           | 1.04         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 777          |
# |    ep_rew_mean          | 94.1         |
# | time/                   |              |
# |    fps                  | 565          |
# |    iterations           | 16           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 1017856      |
# | train/                  |              |
# |    approx_kl            | 0.0047533326 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.101       |
# |    explained_variance   | 0.382        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.73         |
# |    n_updates            | 9930         |
# |    policy_gradient_loss | 0.00122      |
# |    value_loss           | 2.25         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 777          |
# |    ep_rew_mean          | 94.1         |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 17           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 1018880      |
# | train/                  |              |
# |    approx_kl            | 0.0019862403 |
# |    clip_fraction        | 0.0245       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0856      |
# |    explained_variance   | -0.0813      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0196       |
# |    n_updates            | 9940         |
# |    policy_gradient_loss | -0.00151     |
# |    value_loss           | 0.159        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 777          |
# |    ep_rew_mean          | 94           |
# | time/                   |              |
# |    fps                  | 564          |
# |    iterations           | 18           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 1019904      |
# | train/                  |              |
# |    approx_kl            | 0.0012678076 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.088       |
# |    explained_variance   | 0.462        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.399        |
# |    n_updates            | 9950         |
# |    policy_gradient_loss | -0.000102    |
# |    value_loss           | 1.52         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 778          |
# |    ep_rew_mean          | 94.1         |
# | time/                   |              |
# |    fps                  | 563          |
# |    iterations           | 19           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 1020928      |
# | train/                  |              |
# |    approx_kl            | 0.0016727189 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0807      |
# |    explained_variance   | 0.283        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.18         |
# |    n_updates            | 9960         |
# |    policy_gradient_loss | -0.0029      |
# |    value_loss           | 0.944        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 749          |
# |    ep_rew_mean          | 90.5         |
# | time/                   |              |
# |    fps                  | 563          |
# |    iterations           | 20           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 1021952      |
# | train/                  |              |
# |    approx_kl            | 0.0025224115 |
# |    clip_fraction        | 0.0295       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0967      |
# |    explained_variance   | 0.495        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.702        |
# |    n_updates            | 9970         |
# |    policy_gradient_loss | -0.00133     |
# |    value_loss           | 0.872        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 722          |
# |    ep_rew_mean          | 87.2         |
# | time/                   |              |
# |    fps                  | 562          |
# |    iterations           | 21           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 1022976      |
# | train/                  |              |
# |    approx_kl            | 0.0052788947 |
# |    clip_fraction        | 0.0398       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0998      |
# |    explained_variance   | 0.214        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.705        |
# |    n_updates            | 9980         |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 1.52         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 709         |
# |    ep_rew_mean          | 85.6        |
# | time/                   |             |
# |    fps                  | 562         |
# |    iterations           | 22          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 1024000     |
# | train/                  |             |
# |    approx_kl            | 0.011425352 |
# |    clip_fraction        | 0.0486      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.115      |
# |    explained_variance   | 0.237       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.55        |
# |    n_updates            | 9990        |
# |    policy_gradient_loss | -0.00538    |
# |    value_loss           | 3.07        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 702          |
# |    ep_rew_mean          | 84.7         |
# | time/                   |              |
# |    fps                  | 562          |
# |    iterations           | 23           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 1025024      |
# | train/                  |              |
# |    approx_kl            | 0.0021833163 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0906      |
# |    explained_variance   | 0.528        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.631        |
# |    n_updates            | 10000        |
# |    policy_gradient_loss | -0.00233     |
# |    value_loss           | 1.87         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 689          |
# |    ep_rew_mean          | 83.2         |
# | time/                   |              |
# |    fps                  | 561          |
# |    iterations           | 24           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 1026048      |
# | train/                  |              |
# |    approx_kl            | 0.0037602133 |
# |    clip_fraction        | 0.0218       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0928      |
# |    explained_variance   | 0.63         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.269        |
# |    n_updates            | 10010        |
# |    policy_gradient_loss | -0.00192     |
# |    value_loss           | 1.49         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 691          |
# |    ep_rew_mean          | 83.3         |
# | time/                   |              |
# |    fps                  | 561          |
# |    iterations           | 25           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 1027072      |
# | train/                  |              |
# |    approx_kl            | 0.0036640544 |
# |    clip_fraction        | 0.0336       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0949      |
# |    explained_variance   | 0.376        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.483        |
# |    n_updates            | 10020        |
# |    policy_gradient_loss | 0.000544     |
# |    value_loss           | 1.73         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 669        |
# |    ep_rew_mean          | 80.7       |
# | time/                   |            |
# |    fps                  | 561        |
# |    iterations           | 26         |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 1028096    |
# | train/                  |            |
# |    approx_kl            | 0.00415943 |
# |    clip_fraction        | 0.0269     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0838    |
# |    explained_variance   | 0.606      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.53       |
# |    n_updates            | 10030      |
# |    policy_gradient_loss | -0.00141   |
# |    value_loss           | 1.25       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 635          |
# |    ep_rew_mean          | 76.5         |
# | time/                   |              |
# |    fps                  | 561          |
# |    iterations           | 27           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 1029120      |
# | train/                  |              |
# |    approx_kl            | 0.0023872799 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0848      |
# |    explained_variance   | 0.258        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.509        |
# |    n_updates            | 10040        |
# |    policy_gradient_loss | 0.000986     |
# |    value_loss           | 1.07         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 647          |
# |    ep_rew_mean          | 77.9         |
# | time/                   |              |
# |    fps                  | 561          |
# |    iterations           | 28           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 1030144      |
# | train/                  |              |
# |    approx_kl            | 0.0045611775 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0808      |
# |    explained_variance   | 0.479        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.355        |
# |    n_updates            | 10050        |
# |    policy_gradient_loss | 0.000814     |
# |    value_loss           | 1.23         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 625          |
# |    ep_rew_mean          | 75.1         |
# | time/                   |              |
# |    fps                  | 560          |
# |    iterations           | 29           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 1031168      |
# | train/                  |              |
# |    approx_kl            | 0.0011435257 |
# |    clip_fraction        | 0.0269       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0905      |
# |    explained_variance   | 0.189        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.37         |
# |    n_updates            | 10060        |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 3.37         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 612          |
# |    ep_rew_mean          | 73.5         |
# | time/                   |              |
# |    fps                  | 560          |
# |    iterations           | 30           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 1032192      |
# | train/                  |              |
# |    approx_kl            | 0.0018221368 |
# |    clip_fraction        | 0.0189       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0895      |
# |    explained_variance   | 0.472        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.64         |
# |    n_updates            | 10070        |
# |    policy_gradient_loss | 7.71e-05     |
# |    value_loss           | 2.73         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 506          |
# |    ep_rew_mean          | 60.5         |
# | time/                   |              |
# |    fps                  | 560          |
# |    iterations           | 31           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 1033216      |
# | train/                  |              |
# |    approx_kl            | 0.0023309286 |
# |    clip_fraction        | 0.0272       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0819      |
# |    explained_variance   | 0.521        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.15         |
# |    n_updates            | 10080        |
# |    policy_gradient_loss | -0.000733    |
# |    value_loss           | 1.58         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 487          |
# |    ep_rew_mean          | 58           |
# | time/                   |              |
# |    fps                  | 559          |
# |    iterations           | 32           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 1034240      |
# | train/                  |              |
# |    approx_kl            | 0.0027787494 |
# |    clip_fraction        | 0.0177       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.076       |
# |    explained_variance   | 0.473        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.365        |
# |    n_updates            | 10090        |
# |    policy_gradient_loss | 0.000347     |
# |    value_loss           | 0.979        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 454          |
# |    ep_rew_mean          | 54           |
# | time/                   |              |
# |    fps                  | 559          |
# |    iterations           | 33           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 1035264      |
# | train/                  |              |
# |    approx_kl            | 0.0022502122 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0853      |
# |    explained_variance   | 0.327        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33         |
# |    n_updates            | 10100        |
# |    policy_gradient_loss | -0.00176     |
# |    value_loss           | 2.55         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 344          |
# |    ep_rew_mean          | 40.4         |
# | time/                   |              |
# |    fps                  | 558          |
# |    iterations           | 34           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 1036288      |
# | train/                  |              |
# |    approx_kl            | 0.0060272426 |
# |    clip_fraction        | 0.033        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0813      |
# |    explained_variance   | 0.8          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.243        |
# |    n_updates            | 10110        |
# |    policy_gradient_loss | -0.00157     |
# |    value_loss           | 0.558        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 346          |
# |    ep_rew_mean          | 40.6         |
# | time/                   |              |
# |    fps                  | 558          |
# |    iterations           | 35           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 1037312      |
# | train/                  |              |
# |    approx_kl            | 0.0014545766 |
# |    clip_fraction        | 0.033        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0911      |
# |    explained_variance   | 0.339        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.6          |
# |    n_updates            | 10120        |
# |    policy_gradient_loss | -0.00285     |
# |    value_loss           | 3.8          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 354         |
# |    ep_rew_mean          | 41.6        |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 36          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 1038336     |
# | train/                  |             |
# |    approx_kl            | 0.003146259 |
# |    clip_fraction        | 0.0258      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0886     |
# |    explained_variance   | 0.376       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.161       |
# |    n_updates            | 10130       |
# |    policy_gradient_loss | -0.000174   |
# |    value_loss           | 0.757       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 356          |
# |    ep_rew_mean          | 41.9         |
# | time/                   |              |
# |    fps                  | 558          |
# |    iterations           | 37           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 1039360      |
# | train/                  |              |
# |    approx_kl            | 0.0044675106 |
# |    clip_fraction        | 0.028        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0842      |
# |    explained_variance   | 0.368        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.52         |
# |    n_updates            | 10140        |
# |    policy_gradient_loss | -0.0018      |
# |    value_loss           | 2.42         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 362          |
# |    ep_rew_mean          | 42.5         |
# | time/                   |              |
# |    fps                  | 558          |
# |    iterations           | 38           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 1040384      |
# | train/                  |              |
# |    approx_kl            | 0.0016709397 |
# |    clip_fraction        | 0.0252       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0903      |
# |    explained_variance   | -0.0986      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.12         |
# |    n_updates            | 10150        |
# |    policy_gradient_loss | 0.00127      |
# |    value_loss           | 1.58         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 362        |
# |    ep_rew_mean          | 42.6       |
# | time/                   |            |
# |    fps                  | 558        |
# |    iterations           | 39         |
# |    time_elapsed         | 71         |
# |    total_timesteps      | 1041408    |
# | train/                  |            |
# |    approx_kl            | 0.00612964 |
# |    clip_fraction        | 0.043      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0979    |
# |    explained_variance   | 0.367      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.447      |
# |    n_updates            | 10160      |
# |    policy_gradient_loss | -0.00229   |
# |    value_loss           | 1.95       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 362          |
# |    ep_rew_mean          | 42.7         |
# | time/                   |              |
# |    fps                  | 558          |
# |    iterations           | 40           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 1042432      |
# | train/                  |              |
# |    approx_kl            | 0.0023431252 |
# |    clip_fraction        | 0.0217       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0812      |
# |    explained_variance   | 0.82         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.13         |
# |    n_updates            | 10170        |
# |    policy_gradient_loss | -7.48e-05    |
# |    value_loss           | 0.415        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 367          |
# |    ep_rew_mean          | 43.3         |
# | time/                   |              |
# |    fps                  | 558          |
# |    iterations           | 41           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 1043456      |
# | train/                  |              |
# |    approx_kl            | 0.0052050846 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0839      |
# |    explained_variance   | 0.452        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.422        |
# |    n_updates            | 10180        |
# |    policy_gradient_loss | 8.96e-05     |
# |    value_loss           | 1.26         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 380          |
# |    ep_rew_mean          | 44.9         |
# | time/                   |              |
# |    fps                  | 557          |
# |    iterations           | 42           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 1044480      |
# | train/                  |              |
# |    approx_kl            | 0.0055003264 |
# |    clip_fraction        | 0.0369       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0861      |
# |    explained_variance   | 0.179        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0371       |
# |    n_updates            | 10190        |
# |    policy_gradient_loss | -0.0014      |
# |    value_loss           | 0.442        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 381         |
# |    ep_rew_mean          | 45          |
# | time/                   |             |
# |    fps                  | 557         |
# |    iterations           | 43          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 1045504     |
# | train/                  |             |
# |    approx_kl            | 0.001000782 |
# |    clip_fraction        | 0.0209      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0819     |
# |    explained_variance   | 0.289       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.453       |
# |    n_updates            | 10200       |
# |    policy_gradient_loss | -0.000366   |
# |    value_loss           | 1.42        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 386          |
# |    ep_rew_mean          | 45.6         |
# | time/                   |              |
# |    fps                  | 557          |
# |    iterations           | 44           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 1046528      |
# | train/                  |              |
# |    approx_kl            | 0.0024405716 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0787      |
# |    explained_variance   | 0.497        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.489        |
# |    n_updates            | 10210        |
# |    policy_gradient_loss | -0.000284    |
# |    value_loss           | 0.913        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 413          |
# |    ep_rew_mean          | 48.9         |
# | time/                   |              |
# |    fps                  | 557          |
# |    iterations           | 45           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 1047552      |
# | train/                  |              |
# |    approx_kl            | 0.0053450987 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0906      |
# |    explained_variance   | 0.582        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.448        |
# |    n_updates            | 10220        |
# |    policy_gradient_loss | -0.000543    |
# |    value_loss           | 1.36         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 413          |
# |    ep_rew_mean          | 49           |
# | time/                   |              |
# |    fps                  | 557          |
# |    iterations           | 46           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 1048576      |
# | train/                  |              |
# |    approx_kl            | 0.0019540736 |
# |    clip_fraction        | 0.0331       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.109       |
# |    explained_variance   | 0.448        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.893        |
# |    n_updates            | 10230        |
# |    policy_gradient_loss | 0.000202     |
# |    value_loss           | 2.18         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 414          |
# |    ep_rew_mean          | 49.1         |
# | time/                   |              |
# |    fps                  | 557          |
# |    iterations           | 47           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 1049600      |
# | train/                  |              |
# |    approx_kl            | 0.0021172804 |
# |    clip_fraction        | 0.0239       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.105       |
# |    explained_variance   | 0.661        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.242        |
# |    n_updates            | 10240        |
# |    policy_gradient_loss | -0.000859    |
# |    value_loss           | 1.04         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 417          |
# |    ep_rew_mean          | 49.4         |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 48           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 1050624      |
# | train/                  |              |
# |    approx_kl            | 0.0014034223 |
# |    clip_fraction        | 0.0202       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.111       |
# |    explained_variance   | 0.31         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.682        |
# |    n_updates            | 10250        |
# |    policy_gradient_loss | 0.000346     |
# |    value_loss           | 3.12         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 417          |
# |    ep_rew_mean          | 49.4         |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 49           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 1051648      |
# | train/                  |              |
# |    approx_kl            | 0.0013297509 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.118       |
# |    explained_variance   | 0.315        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.923        |
# |    n_updates            | 10260        |
# |    policy_gradient_loss | -0.000277    |
# |    value_loss           | 1.7          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 420         |
# |    ep_rew_mean          | 49.8        |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 50          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 1052672     |
# | train/                  |             |
# |    approx_kl            | 0.005035606 |
# |    clip_fraction        | 0.0342      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0976     |
# |    explained_variance   | -0.602      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.154       |
# |    n_updates            | 10270       |
# |    policy_gradient_loss | 0.00232     |
# |    value_loss           | 0.422       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 412          |
# |    ep_rew_mean          | 48.9         |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 51           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 1053696      |
# | train/                  |              |
# |    approx_kl            | 0.0043911682 |
# |    clip_fraction        | 0.0364       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0856      |
# |    explained_variance   | 0.542        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.404        |
# |    n_updates            | 10280        |
# |    policy_gradient_loss | 0.000823     |
# |    value_loss           | 0.448        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 428          |
# |    ep_rew_mean          | 50.8         |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 52           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 1054720      |
# | train/                  |              |
# |    approx_kl            | 0.0034485427 |
# |    clip_fraction        | 0.0336       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0907      |
# |    explained_variance   | 0.292        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.68         |
# |    n_updates            | 10290        |
# |    policy_gradient_loss | -0.00168     |
# |    value_loss           | 1.21         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 425          |
# |    ep_rew_mean          | 50.5         |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 53           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 1055744      |
# | train/                  |              |
# |    approx_kl            | 0.0006128119 |
# |    clip_fraction        | 0.0119       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0907      |
# |    explained_variance   | 0.113        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.122        |
# |    n_updates            | 10300        |
# |    policy_gradient_loss | 0.000832     |
# |    value_loss           | 0.9          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 426          |
# |    ep_rew_mean          | 50.6         |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 54           |
# ...
# |    ep_len_mean          | 454          |
# |    ep_rew_mean          | 53.9         |
# | time/                   |              |
# |    fps                  | 574          |
# |    iterations           | 472          |
# |    time_elapsed         | 841          |
# |    total_timesteps      | 1484800      |
# | train/                  |              |
# |    approx_kl            | 0.0024007992 |
# |    clip_fraction        | 0.0364       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0821      |
# |    explained_variance   | 0.196        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.766        |
# |    n_updates            | 14490        |
# |    policy_gradient_loss | -0.00313     |
# |    value_loss           | 3.52         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 441          |
# |    ep_rew_mean          | 52.4         |
# | time/                   |              |
# |    fps                  | 574          |
# |    iterations           | 473          |
# |    time_elapsed         | 843          |
# |    total_timesteps      | 1485824      |
# | train/                  |              |
# |    approx_kl            | 0.0056134295 |
# |    clip_fraction        | 0.0335       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0804      |
# |    explained_variance   | 0.181        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.78         |
# |    n_updates            | 14500        |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 1.48         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 461          |
# |    ep_rew_mean          | 54.8         |
# | time/                   |              |
# |    fps                  | 574          |
# |    iterations           | 474          |
# |    time_elapsed         | 845          |
# |    total_timesteps      | 1486848      |
# | train/                  |              |
# |    approx_kl            | 0.0057160743 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0833      |
# |    explained_variance   | 0.362        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.271        |
# |    n_updates            | 14510        |
# |    policy_gradient_loss | -0.00267     |
# |    value_loss           | 1.82         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 460        |
# |    ep_rew_mean          | 54.6       |
# | time/                   |            |
# |    fps                  | 574        |
# |    iterations           | 475        |
# |    time_elapsed         | 847        |
# |    total_timesteps      | 1487872    |
# | train/                  |            |
# |    approx_kl            | 0.00314169 |
# |    clip_fraction        | 0.0163     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.085     |
# |    explained_variance   | 0.483      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.97       |
# |    n_updates            | 14520      |
# |    policy_gradient_loss | -0.00106   |
# |    value_loss           | 1.55       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 460         |
# |    ep_rew_mean          | 54.6        |
# | time/                   |             |
# |    fps                  | 574         |
# |    iterations           | 476         |
# |    time_elapsed         | 848         |
# |    total_timesteps      | 1488896     |
# | train/                  |             |
# |    approx_kl            | 0.009619781 |
# |    clip_fraction        | 0.0351      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0916     |
# |    explained_variance   | 0.67        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0541      |
# |    n_updates            | 14530       |
# |    policy_gradient_loss | -0.0037     |
# |    value_loss           | 0.418       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 483         |
# |    ep_rew_mean          | 57.5        |
# | time/                   |             |
# |    fps                  | 574         |
# |    iterations           | 477         |
# |    time_elapsed         | 850         |
# |    total_timesteps      | 1489920     |
# | train/                  |             |
# |    approx_kl            | 0.010143915 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.112      |
# |    explained_variance   | 0.678       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.146       |
# |    n_updates            | 14540       |
# |    policy_gradient_loss | -0.000738   |
# |    value_loss           | 0.311       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 481          |
# |    ep_rew_mean          | 57.2         |
# | time/                   |              |
# |    fps                  | 574          |
# |    iterations           | 478          |
# |    time_elapsed         | 852          |
# |    total_timesteps      | 1490944      |
# | train/                  |              |
# |    approx_kl            | 0.0009875128 |
# |    clip_fraction        | 0.0263       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0728      |
# |    explained_variance   | 0.164        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.33         |
# |    n_updates            | 14550        |
# |    policy_gradient_loss | -0.00262     |
# |    value_loss           | 3.82         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 493          |
# |    ep_rew_mean          | 58.7         |
# | time/                   |              |
# |    fps                  | 574          |
# |    iterations           | 479          |
# |    time_elapsed         | 853          |
# |    total_timesteps      | 1491968      |
# | train/                  |              |
# |    approx_kl            | 0.0019818344 |
# |    clip_fraction        | 0.0243       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0804      |
# |    explained_variance   | 0.527        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.112        |
# |    n_updates            | 14560        |
# |    policy_gradient_loss | -0.000549    |
# |    value_loss           | 0.87         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 493         |
# |    ep_rew_mean          | 58.7        |
# | time/                   |             |
# |    fps                  | 574         |
# |    iterations           | 480         |
# |    time_elapsed         | 855         |
# |    total_timesteps      | 1492992     |
# | train/                  |             |
# |    approx_kl            | 0.010390835 |
# |    clip_fraction        | 0.0319      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0788     |
# |    explained_variance   | 0.0402      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.24        |
# |    n_updates            | 14570       |
# |    policy_gradient_loss | -0.00234    |
# |    value_loss           | 1.36        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 514          |
# |    ep_rew_mean          | 61.4         |
# | time/                   |              |
# |    fps                  | 574          |
# |    iterations           | 481          |
# |    time_elapsed         | 857          |
# |    total_timesteps      | 1494016      |
# | train/                  |              |
# |    approx_kl            | 0.0026087337 |
# |    clip_fraction        | 0.031        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0803      |
# |    explained_variance   | 0.454        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00661      |
# |    n_updates            | 14580        |
# |    policy_gradient_loss | 0.00247      |
# |    value_loss           | 0.0272       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 502           |
# |    ep_rew_mean          | 59.9          |
# | time/                   |               |
# |    fps                  | 574           |
# |    iterations           | 482           |
# |    time_elapsed         | 858           |
# |    total_timesteps      | 1495040       |
# | train/                  |               |
# |    approx_kl            | 0.00042584466 |
# |    clip_fraction        | 0.0183        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0855       |
# |    explained_variance   | 0.125         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.17          |
# |    n_updates            | 14590         |
# |    policy_gradient_loss | 0.000953      |
# |    value_loss           | 2.19          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 502         |
# |    ep_rew_mean          | 59.9        |
# | time/                   |             |
# |    fps                  | 574         |
# |    iterations           | 483         |
# |    time_elapsed         | 860         |
# |    total_timesteps      | 1496064     |
# | train/                  |             |
# |    approx_kl            | 0.002442488 |
# |    clip_fraction        | 0.0173      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0804     |
# |    explained_variance   | 0.343       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.453       |
# |    n_updates            | 14600       |
# |    policy_gradient_loss | -0.00132    |
# |    value_loss           | 1.18        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 501          |
# |    ep_rew_mean          | 59.7         |
# | time/                   |              |
# |    fps                  | 574          |
# |    iterations           | 484          |
# |    time_elapsed         | 862          |
# |    total_timesteps      | 1497088      |
# | train/                  |              |
# |    approx_kl            | 0.0061600204 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0917      |
# |    explained_variance   | -0.0398      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00657      |
# |    n_updates            | 14610        |
# |    policy_gradient_loss | 8.23e-05     |
# |    value_loss           | 0.0594       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 501         |
# |    ep_rew_mean          | 59.8        |
# | time/                   |             |
# |    fps                  | 574         |
# |    iterations           | 485         |
# |    time_elapsed         | 864         |
# |    total_timesteps      | 1498112     |
# | train/                  |             |
# |    approx_kl            | 0.001745419 |
# |    clip_fraction        | 0.0326      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0875     |
# |    explained_variance   | 0.226       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.201       |
# |    n_updates            | 14620       |
# |    policy_gradient_loss | -0.000531   |
# |    value_loss           | 0.996       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 502          |
# |    ep_rew_mean          | 59.9         |
# | time/                   |              |
# |    fps                  | 574          |
# |    iterations           | 486          |
# |    time_elapsed         | 865          |
# |    total_timesteps      | 1499136      |
# | train/                  |              |
# |    approx_kl            | 0.0024841784 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.097       |
# |    explained_variance   | 0.658        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.573        |
# |    n_updates            | 14630        |
# |    policy_gradient_loss | -0.00223     |
# |    value_loss           | 0.924        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 502         |
# |    ep_rew_mean          | 59.9        |
# | time/                   |             |
# |    fps                  | 574         |
# |    iterations           | 487         |
# |    time_elapsed         | 867         |
# |    total_timesteps      | 1500160     |
# | train/                  |             |
# |    approx_kl            | 0.001235656 |
# |    clip_fraction        | 0.0224      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.089      |
# |    explained_variance   | 0.13        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0214      |
# |    n_updates            | 14640       |
# |    policy_gradient_loss | -0.000418   |
# |    value_loss           | 0.767       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 514         |
# |    ep_rew_mean          | 61.4        |
# | time/                   |             |
# |    fps                  | 574         |
# |    iterations           | 488         |
# |    time_elapsed         | 869         |
# |    total_timesteps      | 1501184     |
# | train/                  |             |
# |    approx_kl            | 0.005091427 |
# |    clip_fraction        | 0.0415      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.107      |
# |    explained_variance   | 0.137       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0612      |
# |    n_updates            | 14650       |
# |    policy_gradient_loss | -6.88e-05   |
# |    value_loss           | 0.0756      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 516          |
# |    ep_rew_mean          | 61.6         |
# | time/                   |              |
# |    fps                  | 574          |
# |    iterations           | 489          |
# |    time_elapsed         | 870          |
# |    total_timesteps      | 1502208      |
# | train/                  |              |
# |    approx_kl            | 0.0036757663 |
# |    clip_fraction        | 0.0363       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.105       |
# |    explained_variance   | 0.12         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.19         |
# |    n_updates            | 14660        |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 1.63         |
# ------------------------------------------

# %%
gym.envs.registration.register(
    id='CustomFlappyBird-v3',
    entry_point='__main__:CustomFlappyBirdEnv_std',
    max_episode_steps=10000000,
)

# Environment erstellen und mit VecMonitor wrappen
env = make_vec_env("CustomFlappyBird-v3", n_envs=4, env_kwargs={'render_mode': 'rgb_array', 'use_lidar': False})

# %%
# Laden des gespeicherten Modells
model = PPO.load("../models/PPO_MLP_gap125_500k")

# Setzen der neuen Umgebung im Modell
model.set_env(env)

# Fortsetzung des Trainings bei 500000 Timestamps und weiter in das gleiche Log-File schreiben
model.set_logger(new_logger)
model.learn(total_timesteps=500000, reset_num_timesteps=False)

# Modell speichern
model.save("../models/PPO_MLP_gap125_500k")
# Out:
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 515          |
# |    ep_rew_mean          | 61.4         |
# | time/                   |              |
# |    fps                  | 1809         |
# |    iterations           | 1            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 1503232      |
# | train/                  |              |
# |    approx_kl            | 0.0037148376 |
# |    clip_fraction        | 0.0276       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.101       |
# |    explained_variance   | 0.0389       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.45         |
# |    n_updates            | 14670        |
# |    policy_gradient_loss | -0.000381    |
# |    value_loss           | 0.83         |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 511       |
# |    ep_rew_mean          | 61        |
# | time/                   |           |
# |    fps                  | 875       |
# |    iterations           | 2         |
# |    time_elapsed         | 2         |
# |    total_timesteps      | 1504256   |
# | train/                  |           |
# |    approx_kl            | 0.0028013 |
# |    clip_fraction        | 0.0286    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0929   |
# |    explained_variance   | -0.0436   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.237     |
# |    n_updates            | 14680     |
# |    policy_gradient_loss | -0.00206  |
# |    value_loss           | 2.64      |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 503          |
# |    ep_rew_mean          | 60           |
# | time/                   |              |
# |    fps                  | 746          |
# |    iterations           | 3            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 1505280      |
# | train/                  |              |
# |    approx_kl            | 0.0022697733 |
# |    clip_fraction        | 0.0302       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0834      |
# |    explained_variance   | 0.306        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.667        |
# |    n_updates            | 14690        |
# |    policy_gradient_loss | -0.00258     |
# |    value_loss           | 2.37         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 486         |
# |    ep_rew_mean          | 57.8        |
# | time/                   |             |
# |    fps                  | 697         |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 1506304     |
# | train/                  |             |
# |    approx_kl            | 0.001199155 |
# |    clip_fraction        | 0.0149      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0858     |
# |    explained_variance   | 0.154       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.38        |
# |    n_updates            | 14700       |
# |    policy_gradient_loss | -9.97e-05   |
# |    value_loss           | 4.22        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 484          |
# |    ep_rew_mean          | 57.6         |
# | time/                   |              |
# |    fps                  | 671          |
# |    iterations           | 5            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 1507328      |
# | train/                  |              |
# |    approx_kl            | 0.0018494083 |
# |    clip_fraction        | 0.031        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0836      |
# |    explained_variance   | 0.471        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.6          |
# |    n_updates            | 14710        |
# |    policy_gradient_loss | -0.00414     |
# |    value_loss           | 3.87         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 457          |
# |    ep_rew_mean          | 54.2         |
# | time/                   |              |
# |    fps                  | 657          |
# |    iterations           | 6            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 1508352      |
# | train/                  |              |
# |    approx_kl            | 0.0014418191 |
# |    clip_fraction        | 0.0252       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0855      |
# |    explained_variance   | 0.577        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.784        |
# |    n_updates            | 14720        |
# |    policy_gradient_loss | -0.00218     |
# |    value_loss           | 2.77         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 443         |
# |    ep_rew_mean          | 52.5        |
# | time/                   |             |
# |    fps                  | 642         |
# |    iterations           | 7           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 1509376     |
# | train/                  |             |
# |    approx_kl            | 0.003408282 |
# |    clip_fraction        | 0.0255      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0753     |
# |    explained_variance   | 0.479       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.25        |
# |    n_updates            | 14730       |
# |    policy_gradient_loss | -0.00253    |
# |    value_loss           | 3.03        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 440          |
# |    ep_rew_mean          | 52.2         |
# | time/                   |              |
# |    fps                  | 632          |
# |    iterations           | 8            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 1510400      |
# | train/                  |              |
# |    approx_kl            | 0.0020801434 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0761      |
# |    explained_variance   | 0.329        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.539        |
# |    n_updates            | 14740        |
# |    policy_gradient_loss | -0.00126     |
# |    value_loss           | 2.19         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 410          |
# |    ep_rew_mean          | 48.4         |
# | time/                   |              |
# |    fps                  | 626          |
# |    iterations           | 9            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 1511424      |
# | train/                  |              |
# |    approx_kl            | 0.0028061233 |
# |    clip_fraction        | 0.0208       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0705      |
# |    explained_variance   | 0.498        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.376        |
# |    n_updates            | 14750        |
# |    policy_gradient_loss | -0.00122     |
# |    value_loss           | 1.21         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 402          |
# |    ep_rew_mean          | 47.4         |
# | time/                   |              |
# |    fps                  | 621          |
# |    iterations           | 10           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 1512448      |
# | train/                  |              |
# |    approx_kl            | 0.0021162024 |
# |    clip_fraction        | 0.0299       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0653      |
# |    explained_variance   | 0.572        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.885        |
# |    n_updates            | 14760        |
# |    policy_gradient_loss | -0.00408     |
# |    value_loss           | 2.47         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 387         |
# |    ep_rew_mean          | 45.5        |
# | time/                   |             |
# |    fps                  | 620         |
# |    iterations           | 11          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 1513472     |
# | train/                  |             |
# |    approx_kl            | 0.003760246 |
# |    clip_fraction        | 0.0237      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0815     |
# |    explained_variance   | 0.394       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.67        |
# |    n_updates            | 14770       |
# |    policy_gradient_loss | -0.00105    |
# |    value_loss           | 1.69        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 360         |
# |    ep_rew_mean          | 42.2        |
# | time/                   |             |
# |    fps                  | 620         |
# |    iterations           | 12          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 1514496     |
# | train/                  |             |
# |    approx_kl            | 0.004062619 |
# |    clip_fraction        | 0.0321      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0817     |
# |    explained_variance   | 0.267       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.387       |
# |    n_updates            | 14780       |
# |    policy_gradient_loss | 0.00084     |
# |    value_loss           | 1.69        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 367         |
# |    ep_rew_mean          | 43.1        |
# | time/                   |             |
# |    fps                  | 619         |
# |    iterations           | 13          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 1515520     |
# | train/                  |             |
# |    approx_kl            | 0.004240456 |
# |    clip_fraction        | 0.0282      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0616     |
# |    explained_variance   | 0.398       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.542       |
# |    n_updates            | 14790       |
# |    policy_gradient_loss | -0.00274    |
# |    value_loss           | 2.26        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 313         |
# |    ep_rew_mean          | 36.5        |
# | time/                   |             |
# |    fps                  | 618         |
# |    iterations           | 14          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 1516544     |
# | train/                  |             |
# |    approx_kl            | 0.004157289 |
# |    clip_fraction        | 0.0361      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0827     |
# |    explained_variance   | 0.544       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.345       |
# |    n_updates            | 14800       |
# |    policy_gradient_loss | -0.000878   |
# |    value_loss           | 1.31        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 286          |
# |    ep_rew_mean          | 33.1         |
# | time/                   |              |
# |    fps                  | 617          |
# |    iterations           | 15           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 1517568      |
# | train/                  |              |
# |    approx_kl            | 0.0023072339 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0631      |
# |    explained_variance   | 0.646        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.599        |
# |    n_updates            | 14810        |
# |    policy_gradient_loss | -0.0034      |
# |    value_loss           | 1.95         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 234          |
# |    ep_rew_mean          | 26.6         |
# | time/                   |              |
# |    fps                  | 617          |
# |    iterations           | 16           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 1518592      |
# | train/                  |              |
# |    approx_kl            | 0.0024058756 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0793      |
# |    explained_variance   | 0.545        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.662        |
# |    n_updates            | 14820        |
# |    policy_gradient_loss | 0.00134      |
# |    value_loss           | 1.76         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 225         |
# |    ep_rew_mean          | 25.5        |
# | time/                   |             |
# |    fps                  | 617         |
# |    iterations           | 17          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 1519616     |
# | train/                  |             |
# |    approx_kl            | 0.002466478 |
# |    clip_fraction        | 0.0238      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0593     |
# |    explained_variance   | 0.341       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.35        |
# |    n_updates            | 14830       |
# |    policy_gradient_loss | -0.00311    |
# |    value_loss           | 2.65        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 215          |
# |    ep_rew_mean          | 24.3         |
# | time/                   |              |
# |    fps                  | 618          |
# |    iterations           | 18           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 1520640      |
# | train/                  |              |
# |    approx_kl            | 0.0024755676 |
# |    clip_fraction        | 0.0212       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.065       |
# |    explained_variance   | 0.445        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.52         |
# |    n_updates            | 14840        |
# |    policy_gradient_loss | -0.00121     |
# |    value_loss           | 2.3          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 188          |
# |    ep_rew_mean          | 21           |
# | time/                   |              |
# |    fps                  | 617          |
# |    iterations           | 19           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 1521664      |
# | train/                  |              |
# |    approx_kl            | 0.0069067813 |
# |    clip_fraction        | 0.0291       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.07        |
# |    explained_variance   | 0.768        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.446        |
# |    n_updates            | 14850        |
# |    policy_gradient_loss | 0.00134      |
# |    value_loss           | 1.11         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 181         |
# |    ep_rew_mean          | 20          |
# | time/                   |             |
# |    fps                  | 617         |
# |    iterations           | 20          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 1522688     |
# | train/                  |             |
# |    approx_kl            | 0.009125011 |
# |    clip_fraction        | 0.0273      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0738     |
# |    explained_variance   | 0.552       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.2         |
# |    n_updates            | 14860       |
# |    policy_gradient_loss | -0.00256    |
# |    value_loss           | 2.13        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 181         |
# |    ep_rew_mean          | 20          |
# | time/                   |             |
# |    fps                  | 616         |
# |    iterations           | 21          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 1523712     |
# | train/                  |             |
# |    approx_kl            | 0.004633438 |
# |    clip_fraction        | 0.0406      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0772     |
# |    explained_variance   | 0.596       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.31        |
# |    n_updates            | 14870       |
# |    policy_gradient_loss | -0.000225   |
# |    value_loss           | 1.5         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 184          |
# |    ep_rew_mean          | 20.5         |
# | time/                   |              |
# |    fps                  | 616          |
# |    iterations           | 22           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 1524736      |
# | train/                  |              |
# |    approx_kl            | 0.0021036537 |
# |    clip_fraction        | 0.0304       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0835      |
# |    explained_variance   | 0.612        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.11         |
# |    n_updates            | 14880        |
# |    policy_gradient_loss | -0.0026      |
# |    value_loss           | 1.58         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 184         |
# |    ep_rew_mean          | 20.5        |
# | time/                   |             |
# |    fps                  | 615         |
# |    iterations           | 23          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 1525760     |
# | train/                  |             |
# |    approx_kl            | 0.005134479 |
# |    clip_fraction        | 0.0326      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0756     |
# |    explained_variance   | 0.587       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02        |
# |    n_updates            | 14890       |
# |    policy_gradient_loss | -0.00231    |
# |    value_loss           | 1.77        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 187          |
# |    ep_rew_mean          | 20.8         |
# | time/                   |              |
# |    fps                  | 615          |
# |    iterations           | 24           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 1526784      |
# | train/                  |              |
# |    approx_kl            | 0.0033619422 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0723      |
# |    explained_variance   | 0.503        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.68         |
# |    n_updates            | 14900        |
# |    policy_gradient_loss | -0.000943    |
# |    value_loss           | 2.7          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 191         |
# |    ep_rew_mean          | 21.3        |
# | time/                   |             |
# |    fps                  | 613         |
# |    iterations           | 25          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 1527808     |
# | train/                  |             |
# |    approx_kl            | 0.002051522 |
# |    clip_fraction        | 0.0231      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0844     |
# |    explained_variance   | 0.461       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.5         |
# |    n_updates            | 14910       |
# |    policy_gradient_loss | 0.000547    |
# |    value_loss           | 1.5         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 192          |
# |    ep_rew_mean          | 21.5         |
# | time/                   |              |
# |    fps                  | 612          |
# |    iterations           | 26           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 1528832      |
# | train/                  |              |
# |    approx_kl            | 0.0014656109 |
# |    clip_fraction        | 0.0266       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0716      |
# |    explained_variance   | 0.0161       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.98         |
# |    n_updates            | 14920        |
# |    policy_gradient_loss | -0.000132    |
# |    value_loss           | 2.22         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 206         |
# |    ep_rew_mean          | 23.1        |
# | time/                   |             |
# |    fps                  | 610         |
# |    iterations           | 27          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 1529856     |
# | train/                  |             |
# |    approx_kl            | 0.004899255 |
# |    clip_fraction        | 0.025       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0614     |
# |    explained_variance   | 0.384       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13        |
# |    n_updates            | 14930       |
# |    policy_gradient_loss | -0.000533   |
# |    value_loss           | 2.29        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 202         |
# |    ep_rew_mean          | 22.7        |
# | time/                   |             |
# |    fps                  | 610         |
# |    iterations           | 28          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 1530880     |
# | train/                  |             |
# |    approx_kl            | 0.003351173 |
# |    clip_fraction        | 0.0245      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0645     |
# |    explained_variance   | 0.612       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.14        |
# |    n_updates            | 14940       |
# |    policy_gradient_loss | -5.63e-05   |
# |    value_loss           | 1.85        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 202          |
# |    ep_rew_mean          | 22.7         |
# | time/                   |              |
# |    fps                  | 609          |
# |    iterations           | 29           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 1531904      |
# | train/                  |              |
# |    approx_kl            | 0.0060137655 |
# |    clip_fraction        | 0.0414       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0798      |
# |    explained_variance   | 0.201        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.528        |
# |    n_updates            | 14950        |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 2.04         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 204          |
# |    ep_rew_mean          | 23           |
# | time/                   |              |
# |    fps                  | 610          |
# |    iterations           | 30           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 1532928      |
# | train/                  |              |
# |    approx_kl            | 0.0015371558 |
# |    clip_fraction        | 0.029        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0777      |
# |    explained_variance   | 0.255        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.209        |
# |    n_updates            | 14960        |
# |    policy_gradient_loss | 0.000227     |
# |    value_loss           | 1.22         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 204          |
# |    ep_rew_mean          | 22.9         |
# | time/                   |              |
# |    fps                  | 610          |
# |    iterations           | 31           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 1533952      |
# | train/                  |              |
# |    approx_kl            | 0.0032939417 |
# |    clip_fraction        | 0.0291       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0758      |
# |    explained_variance   | 0.335        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.759        |
# |    n_updates            | 14970        |
# |    policy_gradient_loss | -0.00329     |
# |    value_loss           | 2.09         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 202          |
# |    ep_rew_mean          | 22.7         |
# | time/                   |              |
# |    fps                  | 607          |
# |    iterations           | 32           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 1534976      |
# | train/                  |              |
# |    approx_kl            | 0.0034003092 |
# |    clip_fraction        | 0.0364       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0935      |
# |    explained_variance   | 0.598        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.794        |
# |    n_updates            | 14980        |
# |    policy_gradient_loss | -0.00655     |
# |    value_loss           | 1.9          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 192          |
# |    ep_rew_mean          | 21.5         |
# | time/                   |              |
# |    fps                  | 606          |
# |    iterations           | 33           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 1536000      |
# | train/                  |              |
# |    approx_kl            | 0.0018379613 |
# |    clip_fraction        | 0.0269       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0878      |
# |    explained_variance   | 0.618        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.614        |
# |    n_updates            | 14990        |
# |    policy_gradient_loss | 0.000316     |
# |    value_loss           | 1.19         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 197          |
# |    ep_rew_mean          | 22.1         |
# | time/                   |              |
# |    fps                  | 606          |
# |    iterations           | 34           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 1537024      |
# | train/                  |              |
# |    approx_kl            | 0.0047170212 |
# |    clip_fraction        | 0.0485       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0946      |
# |    explained_variance   | 0.0792       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.55         |
# |    n_updates            | 15000        |
# |    policy_gradient_loss | -0.00739     |
# |    value_loss           | 3.49         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 196         |
# |    ep_rew_mean          | 22          |
# | time/                   |             |
# |    fps                  | 606         |
# |    iterations           | 35          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 1538048     |
# | train/                  |             |
# |    approx_kl            | 0.013240185 |
# |    clip_fraction        | 0.0407      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0835     |
# |    explained_variance   | 0.372       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.644       |
# |    n_updates            | 15010       |
# |    policy_gradient_loss | -5.35e-05   |
# |    value_loss           | 1.71        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 197         |
# |    ep_rew_mean          | 22.2        |
# | time/                   |             |
# |    fps                  | 605         |
# |    iterations           | 36          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 1539072     |
# | train/                  |             |
# |    approx_kl            | 0.008093417 |
# |    clip_fraction        | 0.0681      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.107      |
# |    explained_variance   | 0.22        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.17        |
# |    n_updates            | 15020       |
# |    policy_gradient_loss | -0.007      |
# |    value_loss           | 3.26        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 201          |
# |    ep_rew_mean          | 22.6         |
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 37           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 1540096      |
# | train/                  |              |
# |    approx_kl            | 0.0023921523 |
# |    clip_fraction        | 0.0298       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0947      |
# |    explained_variance   | 0.527        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14         |
# |    n_updates            | 15030        |
# |    policy_gradient_loss | -0.000485    |
# |    value_loss           | 1.13         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 197         |
# |    ep_rew_mean          | 22.1        |
# | time/                   |             |
# |    fps                  | 606         |
# |    iterations           | 38          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 1541120     |
# | train/                  |             |
# |    approx_kl            | 0.002627241 |
# |    clip_fraction        | 0.0316      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0933     |
# |    explained_variance   | 0.361       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.42        |
# |    n_updates            | 15040       |
# |    policy_gradient_loss | -0.00056    |
# |    value_loss           | 2.44        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 22.4         |
# | time/                   |              |
# |    fps                  | 606          |
# |    iterations           | 39           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 1542144      |
# | train/                  |              |
# |    approx_kl            | 0.0027805725 |
# |    clip_fraction        | 0.0362       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0988      |
# |    explained_variance   | 0.406        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.742        |
# |    n_updates            | 15050        |
# |    policy_gradient_loss | -0.0032      |
# |    value_loss           | 1.82         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 202          |
# |    ep_rew_mean          | 22.8         |
# | time/                   |              |
# |    fps                  | 607          |
# |    iterations           | 40           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 1543168      |
# | train/                  |              |
# |    approx_kl            | 0.0019943595 |
# |    clip_fraction        | 0.0341       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0891      |
# |    explained_variance   | 0.398        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.31         |
# |    n_updates            | 15060        |
# |    policy_gradient_loss | 0.00045      |
# |    value_loss           | 2.6          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 203          |
# |    ep_rew_mean          | 22.9         |
# | time/                   |              |
# |    fps                  | 607          |
# |    iterations           | 41           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 1544192      |
# | train/                  |              |
# |    approx_kl            | 0.0030238314 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0988      |
# |    explained_variance   | 0.389        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.955        |
# |    n_updates            | 15070        |
# |    policy_gradient_loss | -0.00148     |
# |    value_loss           | 2.45         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 202          |
# |    ep_rew_mean          | 22.7         |
# | time/                   |              |
# |    fps                  | 608          |
# |    iterations           | 42           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 1545216      |
# | train/                  |              |
# |    approx_kl            | 0.0019542724 |
# |    clip_fraction        | 0.0286       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0894      |
# |    explained_variance   | 0.319        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.761        |
# |    n_updates            | 15080        |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 1.74         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 205          |
# |    ep_rew_mean          | 23.1         |
# | time/                   |              |
# |    fps                  | 609          |
# |    iterations           | 43           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 1546240      |
# | train/                  |              |
# |    approx_kl            | 0.0041217837 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0982      |
# |    explained_variance   | 0.479        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.43         |
# |    n_updates            | 15090        |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 1.72         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 215          |
# |    ep_rew_mean          | 24.4         |
# | time/                   |              |
# |    fps                  | 609          |
# |    iterations           | 44           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 1547264      |
# | train/                  |              |
# |    approx_kl            | 0.0034728649 |
# |    clip_fraction        | 0.0507       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0897      |
# |    explained_variance   | 0.411        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.545        |
# |    n_updates            | 15100        |
# |    policy_gradient_loss | -0.00135     |
# |    value_loss           | 1.22         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 220          |
# |    ep_rew_mean          | 24.9         |
# | time/                   |              |
# |    fps                  | 608          |
# |    iterations           | 45           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 1548288      |
# | train/                  |              |
# |    approx_kl            | 0.0038405592 |
# |    clip_fraction        | 0.0444       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0893      |
# |    explained_variance   | 0.374        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.53         |
# |    n_updates            | 15110        |
# |    policy_gradient_loss | -0.00375     |
# |    value_loss           | 1.69         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 227          |
# |    ep_rew_mean          | 25.8         |
# | time/                   |              |
# |    fps                  | 608          |
# |    iterations           | 46           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 1549312      |
# | train/                  |              |
# |    approx_kl            | 0.0037734853 |
# |    clip_fraction        | 0.0393       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0864      |
# |    explained_variance   | 0.0248       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.795        |
# |    n_updates            | 15120        |
# |    policy_gradient_loss | -0.0021      |
# |    value_loss           | 2.09         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 225          |
# |    ep_rew_mean          | 25.5         |
# | time/                   |              |
# |    fps                  | 609          |
# |    iterations           | 47           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 1550336      |
# | train/                  |              |
# |    approx_kl            | 0.0048957425 |
# |    clip_fraction        | 0.0255       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0816      |
# |    explained_variance   | 0.243        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.427        |
# |    n_updates            | 15130        |
# |    policy_gradient_loss | -0.000395    |
# |    value_loss           | 1.38         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 224          |
# |    ep_rew_mean          | 25.5         |
# | time/                   |              |
# |    fps                  | 610          |
# |    iterations           | 48           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 1551360      |
# | train/                  |              |
# |    approx_kl            | 0.0082688145 |
# |    clip_fraction        | 0.0358       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0887      |
# |    explained_variance   | 0.427        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.347        |
# |    n_updates            | 15140        |
# |    policy_gradient_loss | -0.000996    |
# |    value_loss           | 1.04         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 211          |
# |    ep_rew_mean          | 23.9         |
# | time/                   |              |
# |    fps                  | 610          |
# |    iterations           | 49           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 1552384      |
# | train/                  |              |
# |    approx_kl            | 0.0025906148 |
# |    clip_fraction        | 0.0254       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0789      |
# |    explained_variance   | 0.411        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.79         |
# |    n_updates            | 15150        |
# |    policy_gradient_loss | -0.000712    |
# |    value_loss           | 4.03         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 202          |
# |    ep_rew_mean          | 22.7         |
# | time/                   |              |
# |    fps                  | 610          |
# |    iterations           | 50           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 1553408      |
# | train/                  |              |
# |    approx_kl            | 0.0048092795 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0851      |
# |    explained_variance   | 0.638        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.27         |
# |    n_updates            | 15160        |
# |    policy_gradient_loss | -0.00476     |
# |    value_loss           | 2.87         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 203          |
# |    ep_rew_mean          | 22.9         |
# | time/                   |              |
# |    fps                  | 610          |
# |    iterations           | 51           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 1554432      |
# | train/                  |              |
# |    approx_kl            | 0.0031538978 |
# |    clip_fraction        | 0.0364       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0978      |
# |    explained_variance   | 0.653        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.02         |
# |    n_updates            | 15170        |
# |    policy_gradient_loss | -0.0028      |
# |    value_loss           | 1.55         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 210         |
# |    ep_rew_mean          | 23.7        |
# | time/                   |             |
# |    fps                  | 610         |
# |    iterations           | 52          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 1555456     |
# | train/                  |             |
# |    approx_kl            | 0.007345224 |
# |    clip_fraction        | 0.0369      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0867     |
# |    explained_variance   | 0.619       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.533       |
# |    n_updates            | 15180       |
# |    policy_gradient_loss | -0.000258   |
# |    value_loss           | 1.26        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 208          |
# |    ep_rew_mean          | 23.5         |
# | time/                   |              |
# |    fps                  | 608          |
# |    iterations           | 53           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 1556480      |
# | train/                  |              |
# |    approx_kl            | 0.0024156533 |
# |    clip_fraction        | 0.0518       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.105       |
# |    explained_variance   | 0.391        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.43         |
# |    n_updates            | 15190        |
# |    policy_gradient_loss | -0.00305     |
# |    value_loss           | 2.38         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 208         |
# |    ep_rew_mean          | 23.5        |
# | time/                   |             |
# |    fps                  | 607         |
# |    iterations           | 54          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 1557504     |
# | train/                  |             |
# |    approx_kl            | 0.003075908 |
# |    clip_fraction        | 0.0448      |
# |    clip_range           | 0.2         |
# ...
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 620         |
# |    ep_rew_mean          | 74.6        |
# | time/                   |             |
# |    fps                  | 582         |
# |    iterations           | 472         |
# |    time_elapsed         | 829         |
# |    total_timesteps      | 1985536     |
# | train/                  |             |
# |    approx_kl            | 0.005567394 |
# |    clip_fraction        | 0.0284      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0694     |
# |    explained_variance   | 0.401       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.108       |
# |    n_updates            | 19380       |
# |    policy_gradient_loss | -0.000859   |
# |    value_loss           | 1.44        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 609         |
# |    ep_rew_mean          | 73.2        |
# | time/                   |             |
# |    fps                  | 582         |
# |    iterations           | 473         |
# |    time_elapsed         | 831         |
# |    total_timesteps      | 1986560     |
# | train/                  |             |
# |    approx_kl            | 0.003187146 |
# |    clip_fraction        | 0.0245      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0722     |
# |    explained_variance   | 0.385       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.343       |
# |    n_updates            | 19390       |
# |    policy_gradient_loss | -0.000232   |
# |    value_loss           | 0.718       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 603         |
# |    ep_rew_mean          | 72.5        |
# | time/                   |             |
# |    fps                  | 582         |
# |    iterations           | 474         |
# |    time_elapsed         | 833         |
# |    total_timesteps      | 1987584     |
# | train/                  |             |
# |    approx_kl            | 0.005225982 |
# |    clip_fraction        | 0.0458      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0822     |
# |    explained_variance   | 0.186       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.817       |
# |    n_updates            | 19400       |
# |    policy_gradient_loss | -0.00401    |
# |    value_loss           | 2.72        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 602          |
# |    ep_rew_mean          | 72.4         |
# | time/                   |              |
# |    fps                  | 582          |
# |    iterations           | 475          |
# |    time_elapsed         | 835          |
# |    total_timesteps      | 1988608      |
# | train/                  |              |
# |    approx_kl            | 0.0008121376 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0735      |
# |    explained_variance   | 0.0271       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.475        |
# |    n_updates            | 19410        |
# |    policy_gradient_loss | -0.000509    |
# |    value_loss           | 1.72         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 577          |
# |    ep_rew_mean          | 69.3         |
# | time/                   |              |
# |    fps                  | 581          |
# |    iterations           | 476          |
# |    time_elapsed         | 837          |
# |    total_timesteps      | 1989632      |
# | train/                  |              |
# |    approx_kl            | 0.0015628797 |
# |    clip_fraction        | 0.0209       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0743      |
# |    explained_variance   | 0.22         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.646        |
# |    n_updates            | 19420        |
# |    policy_gradient_loss | -0.00249     |
# |    value_loss           | 2.4          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 555         |
# |    ep_rew_mean          | 66.6        |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 477         |
# |    time_elapsed         | 839         |
# |    total_timesteps      | 1990656     |
# | train/                  |             |
# |    approx_kl            | 0.005475316 |
# |    clip_fraction        | 0.0438      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0809     |
# |    explained_variance   | -0.0702     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.62        |
# |    n_updates            | 19430       |
# |    policy_gradient_loss | -0.00429    |
# |    value_loss           | 3.17        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 550         |
# |    ep_rew_mean          | 65.9        |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 478         |
# |    time_elapsed         | 841         |
# |    total_timesteps      | 1991680     |
# | train/                  |             |
# |    approx_kl            | 0.005956866 |
# |    clip_fraction        | 0.0254      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.077      |
# |    explained_variance   | 0.45        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1         |
# |    n_updates            | 19440       |
# |    policy_gradient_loss | 0.00278     |
# |    value_loss           | 1.68        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 517         |
# |    ep_rew_mean          | 61.8        |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 479         |
# |    time_elapsed         | 843         |
# |    total_timesteps      | 1992704     |
# | train/                  |             |
# |    approx_kl            | 0.007564886 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0809     |
# |    explained_variance   | 0.302       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1         |
# |    n_updates            | 19450       |
# |    policy_gradient_loss | -0.00269    |
# |    value_loss           | 2.23        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 513         |
# |    ep_rew_mean          | 61.4        |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 480         |
# |    time_elapsed         | 845         |
# |    total_timesteps      | 1993728     |
# | train/                  |             |
# |    approx_kl            | 0.002770904 |
# |    clip_fraction        | 0.0282      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0766     |
# |    explained_variance   | 0.381       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.17        |
# |    n_updates            | 19460       |
# |    policy_gradient_loss | -0.00329    |
# |    value_loss           | 2.69        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 516          |
# |    ep_rew_mean          | 61.7         |
# | time/                   |              |
# |    fps                  | 580          |
# |    iterations           | 481          |
# |    time_elapsed         | 847          |
# |    total_timesteps      | 1994752      |
# | train/                  |              |
# |    approx_kl            | 0.0038616075 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0751      |
# |    explained_variance   | -0.234       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.371        |
# |    n_updates            | 19470        |
# |    policy_gradient_loss | -0.00223     |
# |    value_loss           | 0.934        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 516        |
# |    ep_rew_mean          | 61.8       |
# | time/                   |            |
# |    fps                  | 580        |
# |    iterations           | 482        |
# |    time_elapsed         | 849        |
# |    total_timesteps      | 1995776    |
# | train/                  |            |
# |    approx_kl            | 0.00426392 |
# |    clip_fraction        | 0.0382     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0722    |
# |    explained_variance   | 0.234      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.27       |
# |    n_updates            | 19480      |
# |    policy_gradient_loss | -0.00305   |
# |    value_loss           | 2.14       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 513          |
# |    ep_rew_mean          | 61.3         |
# | time/                   |              |
# |    fps                  | 580          |
# |    iterations           | 483          |
# |    time_elapsed         | 851          |
# |    total_timesteps      | 1996800      |
# | train/                  |              |
# |    approx_kl            | 0.0034781918 |
# |    clip_fraction        | 0.0251       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0619      |
# |    explained_variance   | 0.169        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.143        |
# |    n_updates            | 19490        |
# |    policy_gradient_loss | 0.000797     |
# |    value_loss           | 1.2          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 510         |
# |    ep_rew_mean          | 61          |
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 484         |
# |    time_elapsed         | 853         |
# |    total_timesteps      | 1997824     |
# | train/                  |             |
# |    approx_kl            | 0.002617508 |
# |    clip_fraction        | 0.0269      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0679     |
# |    explained_variance   | 0.282       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0899      |
# |    n_updates            | 19500       |
# |    policy_gradient_loss | 0.000339    |
# |    value_loss           | 0.805       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 510          |
# |    ep_rew_mean          | 61           |
# | time/                   |              |
# |    fps                  | 580          |
# |    iterations           | 485          |
# |    time_elapsed         | 856          |
# |    total_timesteps      | 1998848      |
# | train/                  |              |
# |    approx_kl            | 0.0036750636 |
# |    clip_fraction        | 0.0238       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0639      |
# |    explained_variance   | 0.289        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.754        |
# |    n_updates            | 19510        |
# |    policy_gradient_loss | -0.00289     |
# |    value_loss           | 2.66         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 510         |
# |    ep_rew_mean          | 61          |
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 486         |
# |    time_elapsed         | 857         |
# |    total_timesteps      | 1999872     |
# | train/                  |             |
# |    approx_kl            | 0.015202881 |
# |    clip_fraction        | 0.0402      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0642     |
# |    explained_variance   | -0.995      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0303      |
# |    n_updates            | 19520       |
# |    policy_gradient_loss | -0.000372   |
# |    value_loss           | 0.128       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 510         |
# |    ep_rew_mean          | 61          |
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 487         |
# |    time_elapsed         | 859         |
# |    total_timesteps      | 2000896     |
# | train/                  |             |
# |    approx_kl            | 0.008928657 |
# |    clip_fraction        | 0.0326      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0696     |
# |    explained_variance   | -0.155      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0313      |
# |    n_updates            | 19530       |
# |    policy_gradient_loss | 0.000424    |
# |    value_loss           | 0.0547      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 510         |
# |    ep_rew_mean          | 60.9        |
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 488         |
# |    time_elapsed         | 861         |
# |    total_timesteps      | 2001920     |
# | train/                  |             |
# |    approx_kl            | 0.003974837 |
# |    clip_fraction        | 0.0308      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0708     |
# |    explained_variance   | 0.637       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00624     |
# |    n_updates            | 19540       |
# |    policy_gradient_loss | 0.00162     |
# |    value_loss           | 0.023       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 521         |
# |    ep_rew_mean          | 62.4        |
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 489         |
# |    time_elapsed         | 863         |
# |    total_timesteps      | 2002944     |
# | train/                  |             |
# |    approx_kl            | 0.005108695 |
# |    clip_fraction        | 0.0377      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0745     |
# |    explained_variance   | -0.0342     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.38        |
# |    n_updates            | 19550       |
# |    policy_gradient_loss | -0.00197    |
# |    value_loss           | 1.21        |
# -----------------------------------------
