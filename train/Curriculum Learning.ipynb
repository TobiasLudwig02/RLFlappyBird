# %%
from flappy_bird_gymnasium.envs.flappy_bird_env import FlappyBirdEnv
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.logger import configure
import os

# %%
class CustomFlappyBirdEnv_gap300(FlappyBirdEnv):
    def __init__(self, render_mode=None, use_lidar=False, **kwargs):
        super(CustomFlappyBirdEnv_gap300, self).__init__(render_mode=render_mode, use_lidar=use_lidar, **kwargs)
        self.pipe_gap = 300  # Beispiel: Änderung des Abstands zwischen den Rohren
        self.gravity = 0.5  # Beispiel: Änderung der Schwerkraft

    def _get_reward(self):
        reward = 0.1  # +0.1 - every frame it stays alive
        if self.player['y'] + self.player['h'] >= self.screen_height:
            reward = -1.0  # -1.0 - dying
        elif self.player['y'] <= 0:
            reward = -0.5 # -0.5 - touch the top of the screen
        elif self.pipe_passed:
            reward = 1  # +1.0 - successfully passing a pipe
        return reward

# %%
# Log-Directory und Dateiname für den Callback festlegen
log_dir = "./logs/"
os.makedirs(log_dir, exist_ok=True)
custom_log_file = os.path.join(log_dir, "Curriculum_Learning")

# Configure the logger to save data to a specific folder
new_logger = configure(custom_log_file, ["stdout", "csv"])
# Out:
# Logging to ./logs/Curriculum_Learning

# %%
gym.envs.registration.register(
    id='CustomFlappyBird-v0',
    entry_point='__main__:CustomFlappyBirdEnv_gap300',
    max_episode_steps=10000000,
)

# Environment erstellen und mit VecMonitor wrappen
env = make_vec_env("CustomFlappyBird-v0", n_envs=4, env_kwargs={'render_mode': 'rgb_array', 'use_lidar': False})

# %%
# PPO Modell definieren
model = PPO(
    "MlpPolicy", 
    env, 
    learning_rate=3e-4, 
    n_steps=256, 
    batch_size=64, 
    n_epochs=10, 
    gamma=0.99, 
    ent_coef=0.01,
    verbose=1,
    device='cuda'
)

# Attach the new logger to the model
model.set_logger(new_logger)

# Modell trainieren mit Callback
model.learn(total_timesteps=500000)

# Modell speichern
model.save("models/PPO_MLP_gap300_500k")
# Out:
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -7.44    |
# | time/              |          |
# |    fps             | 659      |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1024     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -7.86       |
# | time/                   |             |
# |    fps                  | 379         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.014217062 |
# |    clip_fraction        | 0.0236      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.684      |
# |    explained_variance   | -0.018      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00285    |
# |    value_loss           | 4.14        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -7.81        |
# | time/                   |              |
# |    fps                  | 378          |
# |    iterations           | 3            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0031047515 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | 0.346        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.372        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | 1.41e-05     |
# |    value_loss           | 2.24         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -7.51       |
# | time/                   |             |
# |    fps                  | 377         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015787113 |
# |    clip_fraction        | 0.0464      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.689      |
# |    explained_variance   | 0.688       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.379       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00303    |
# |    value_loss           | 0.968       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -7.29       |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 5           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.018653944 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.657      |
# |    explained_variance   | 0.694       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.577       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0219     |
# |    value_loss           | 1.11        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -6.68       |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 6           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011158655 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.604      |
# |    explained_variance   | 0.787       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.335       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 0.766       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -5.04       |
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 7           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.010395649 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.548      |
# |    explained_variance   | 0.4         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.869       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 2.15        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -3.53        |
# | time/                   |              |
# |    fps                  | 375          |
# |    iterations           | 8            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0066103437 |
# |    clip_fraction        | 0.0967       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.491       |
# |    explained_variance   | 0.207        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.811        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0106      |
# |    value_loss           | 1.82         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.6        |
# |    ep_rew_mean          | -1.21       |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 9           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.008542804 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.41       |
# |    explained_variance   | 0.439       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.562       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 1.69        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.4        |
# |    ep_rew_mean          | 0.832       |
# | time/                   |             |
# |    fps                  | 377         |
# |    iterations           | 10          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006184517 |
# |    clip_fraction        | 0.09        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.321      |
# |    explained_variance   | 0.126       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.21        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.765       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 48.9      |
# |    ep_rew_mean          | 2.28      |
# | time/                   |           |
# |    fps                  | 371       |
# |    iterations           | 11        |
# |    time_elapsed         | 30        |
# |    total_timesteps      | 11264     |
# | train/                  |           |
# |    approx_kl            | 0.0041794 |
# |    clip_fraction        | 0.0543    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.254    |
# |    explained_variance   | 0.225     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.238     |
# |    n_updates            | 100       |
# |    policy_gradient_loss | -0.00513  |
# |    value_loss           | 0.472     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.6        |
# |    ep_rew_mean          | 3.08        |
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 12          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.027017739 |
# |    clip_fraction        | 0.0683      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.295      |
# |    explained_variance   | 0.541       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.109       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 0.298       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50.5         |
# |    ep_rew_mean          | 3.86         |
# | time/                   |              |
# |    fps                  | 377          |
# |    iterations           | 13           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 0.0025175752 |
# |    clip_fraction        | 0.0268       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.228       |
# |    explained_variance   | 0.77         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.106        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00403     |
# |    value_loss           | 0.255        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 51.5         |
# |    ep_rew_mean          | 4.05         |
# | time/                   |              |
# |    fps                  | 377          |
# |    iterations           | 14           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0014701566 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.208       |
# |    explained_variance   | 0.86         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.122        |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00345     |
# |    value_loss           | 0.201        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 53           |
# |    ep_rew_mean          | 4.33         |
# | time/                   |              |
# |    fps                  | 379          |
# |    iterations           | 15           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 0.0029290025 |
# |    clip_fraction        | 0.0349       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.197       |
# |    explained_variance   | 0.83         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.111        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00287     |
# |    value_loss           | 0.226        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 54.7         |
# |    ep_rew_mean          | 4.51         |
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 16           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0034597788 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.18        |
# |    explained_variance   | 0.792        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.11         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00393     |
# |    value_loss           | 0.3          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.1        |
# |    ep_rew_mean          | 4.68        |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 17          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.001601578 |
# |    clip_fraction        | 0.0203      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.175      |
# |    explained_variance   | 0.825       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.121       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00179    |
# |    value_loss           | 0.286       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 57.2         |
# |    ep_rew_mean          | 4.84         |
# | time/                   |              |
# |    fps                  | 385          |
# |    iterations           | 18           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0029875594 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.163       |
# |    explained_variance   | 0.73         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.17         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00341     |
# |    value_loss           | 0.367        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 57.2          |
# |    ep_rew_mean          | 4.83          |
# | time/                   |               |
# |    fps                  | 384           |
# |    iterations           | 19            |
# |    time_elapsed         | 50            |
# |    total_timesteps      | 19456         |
# | train/                  |               |
# |    approx_kl            | 0.00070030167 |
# |    clip_fraction        | 0.012         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.146        |
# |    explained_variance   | 0.798         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.103         |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000803     |
# |    value_loss           | 0.334         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 57.9         |
# |    ep_rew_mean          | 4.92         |
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 20           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0012531161 |
# |    clip_fraction        | 0.0313       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.182       |
# |    explained_variance   | 0.818        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.127        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00231     |
# |    value_loss           | 0.299        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 58.4         |
# |    ep_rew_mean          | 5.01         |
# | time/                   |              |
# |    fps                  | 388          |
# |    iterations           | 21           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 21504        |
# | train/                  |              |
# |    approx_kl            | 0.0017192896 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.155       |
# |    explained_variance   | 0.799        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.201        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00309     |
# |    value_loss           | 0.312        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60.2         |
# |    ep_rew_mean          | 5.25         |
# | time/                   |              |
# |    fps                  | 389          |
# |    iterations           | 22           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0019267853 |
# |    clip_fraction        | 0.0437       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.154       |
# |    explained_variance   | 0.824        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.146        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00431     |
# |    value_loss           | 0.282        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 59.5         |
# |    ep_rew_mean          | 5.14         |
# | time/                   |              |
# |    fps                  | 391          |
# |    iterations           | 23           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0018649464 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.143       |
# |    explained_variance   | 0.668        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.237        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00183     |
# |    value_loss           | 0.472        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 5.31         |
# | time/                   |              |
# |    fps                  | 390          |
# |    iterations           | 24           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0015133799 |
# |    clip_fraction        | 0.0304       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.146       |
# |    explained_variance   | 0.696        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.158        |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0024      |
# |    value_loss           | 0.475        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61.8         |
# |    ep_rew_mean          | 5.41         |
# | time/                   |              |
# |    fps                  | 392          |
# |    iterations           | 25           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 0.0019840105 |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.134       |
# |    explained_variance   | 0.78         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.194        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0039      |
# |    value_loss           | 0.395        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 62           |
# |    ep_rew_mean          | 5.44         |
# | time/                   |              |
# |    fps                  | 392          |
# |    iterations           | 26           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0018198171 |
# |    clip_fraction        | 0.0174       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.109       |
# |    explained_variance   | 0.777        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.192        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0019      |
# |    value_loss           | 0.407        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 63.3         |
# |    ep_rew_mean          | 5.59         |
# | time/                   |              |
# |    fps                  | 392          |
# |    iterations           | 27           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 27648        |
# | train/                  |              |
# |    approx_kl            | 0.0015766459 |
# |    clip_fraction        | 0.0194       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.126       |
# |    explained_variance   | 0.774        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.194        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00329     |
# |    value_loss           | 0.372        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 63.2         |
# |    ep_rew_mean          | 5.6          |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 28           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0013099333 |
# |    clip_fraction        | 0.00967      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.108       |
# |    explained_variance   | 0.755        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.216        |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00129     |
# |    value_loss           | 0.442        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 64.5          |
# |    ep_rew_mean          | 5.76          |
# | time/                   |               |
# |    fps                  | 392           |
# |    iterations           | 29            |
# |    time_elapsed         | 75            |
# |    total_timesteps      | 29696         |
# | train/                  |               |
# |    approx_kl            | 0.00010532839 |
# |    clip_fraction        | 0.00693       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.12         |
# |    explained_variance   | 0.749         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.236         |
# |    n_updates            | 280           |
# |    policy_gradient_loss | 0.000235      |
# |    value_loss           | 0.422         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 64.8         |
# |    ep_rew_mean          | 5.81         |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 30           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0022380413 |
# |    clip_fraction        | 0.0301       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.103       |
# |    explained_variance   | 0.824        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0952       |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00302     |
# |    value_loss           | 0.346        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 66           |
# |    ep_rew_mean          | 5.97         |
# | time/                   |              |
# |    fps                  | 395          |
# |    iterations           | 31           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 0.0007667864 |
# |    clip_fraction        | 0.0226       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.121       |
# |    explained_variance   | 0.753        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.39         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00148     |
# |    value_loss           | 0.514        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 66.9        |
# |    ep_rew_mean          | 6.09        |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 32          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.002413887 |
# |    clip_fraction        | 0.0307      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.111      |
# |    explained_variance   | 0.743       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.222       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00186    |
# |    value_loss           | 0.497       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 69.4         |
# |    ep_rew_mean          | 6.39         |
# | time/                   |              |
# |    fps                  | 393          |
# |    iterations           | 33           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 33792        |
# | train/                  |              |
# |    approx_kl            | 0.0014366228 |
# |    clip_fraction        | 0.0213       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.108       |
# |    explained_variance   | 0.693        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.32         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00118     |
# |    value_loss           | 0.637        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 69.9         |
# |    ep_rew_mean          | 6.45         |
# | time/                   |              |
# |    fps                  | 392          |
# |    iterations           | 34           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0015284616 |
# |    clip_fraction        | 0.0116       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0893      |
# |    explained_variance   | 0.695        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.384        |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000804    |
# |    value_loss           | 0.618        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 69.3         |
# |    ep_rew_mean          | 6.38         |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 35           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 35840        |
# | train/                  |              |
# |    approx_kl            | 0.0009487622 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0899      |
# |    explained_variance   | 0.607        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.274        |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000144    |
# |    value_loss           | 0.763        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 69.7         |
# |    ep_rew_mean          | 6.42         |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 36           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0031976951 |
# |    clip_fraction        | 0.0186       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0913      |
# |    explained_variance   | 0.698        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.296        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00075     |
# |    value_loss           | 0.659        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 71           |
# |    ep_rew_mean          | 6.6          |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 37           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 37888        |
# | train/                  |              |
# |    approx_kl            | 0.0012919224 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0855      |
# |    explained_variance   | 0.669        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.561        |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00146     |
# |    value_loss           | 0.697        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 72           |
# |    ep_rew_mean          | 6.71         |
# | time/                   |              |
# |    fps                  | 396          |
# |    iterations           | 38           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0017055959 |
# |    clip_fraction        | 0.0391       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0718      |
# |    explained_variance   | 0.69         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.273        |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00465     |
# |    value_loss           | 0.554        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 72.5         |
# |    ep_rew_mean          | 6.76         |
# | time/                   |              |
# |    fps                  | 393          |
# |    iterations           | 39           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 39936        |
# | train/                  |              |
# |    approx_kl            | 0.0023310243 |
# |    clip_fraction        | 0.017        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.078       |
# |    explained_variance   | 0.571        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.422        |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000381    |
# |    value_loss           | 0.889        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 73.6         |
# |    ep_rew_mean          | 6.9          |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 40           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0057690456 |
# |    clip_fraction        | 0.0376       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0973      |
# |    explained_variance   | 0.558        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.571        |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00577     |
# |    value_loss           | 0.989        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 74.6         |
# |    ep_rew_mean          | 7.01         |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 41           |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 41984        |
# | train/                  |              |
# |    approx_kl            | 0.0015448458 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0793      |
# |    explained_variance   | 0.563        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.398        |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00322     |
# |    value_loss           | 0.939        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 77.2         |
# |    ep_rew_mean          | 7.36         |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 42           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0028852788 |
# |    clip_fraction        | 0.0218       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0854      |
# |    explained_variance   | 0.69         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.624        |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00042     |
# |    value_loss           | 0.791        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 79.1         |
# |    ep_rew_mean          | 7.6          |
# | time/                   |              |
# |    fps                  | 395          |
# |    iterations           | 43           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 44032        |
# | train/                  |              |
# |    approx_kl            | 0.0011494085 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0778      |
# |    explained_variance   | 0.543        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.275        |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00144     |
# |    value_loss           | 0.947        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 81.4         |
# |    ep_rew_mean          | 7.88         |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 44           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0025027965 |
# |    clip_fraction        | 0.0311       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0695      |
# |    explained_variance   | 0.51         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.355        |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00384     |
# |    value_loss           | 1.13         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 83.8         |
# |    ep_rew_mean          | 8.17         |
# | time/                   |              |
# |    fps                  | 395          |
# |    iterations           | 45           |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 46080        |
# | train/                  |              |
# |    approx_kl            | 0.0014047611 |
# |    clip_fraction        | 0.017        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0703      |
# |    explained_variance   | 0.566        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.506        |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000692    |
# |    value_loss           | 0.995        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 85.1         |
# |    ep_rew_mean          | 8.33         |
# | time/                   |              |
# |    fps                  | 396          |
# |    iterations           | 46           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0007448329 |
# |    clip_fraction        | 0.0222       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0626      |
# |    explained_variance   | 0.591        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.474        |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 1.15         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 86.8         |
# |    ep_rew_mean          | 8.53         |
# | time/                   |              |
# |    fps                  | 396          |
# |    iterations           | 47           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 48128        |
# | train/                  |              |
# |    approx_kl            | 0.0014987099 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0698      |
# |    explained_variance   | 0.618        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.596        |
# |    n_updates            | 460          |
# |    policy_gradient_loss | 0.000593     |
# |    value_loss           | 1.03         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.5        |
# |    ep_rew_mean          | 8.5         |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 48          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004667244 |
# |    clip_fraction        | 0.0472      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0898     |
# |    explained_variance   | 0.458       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.403       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00466    |
# |    value_loss           | 1.44        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 87.7       |
# |    ep_rew_mean          | 8.65       |
# | time/                   |            |
# |    fps                  | 397        |
# |    iterations           | 49         |
# |    time_elapsed         | 126        |
# |    total_timesteps      | 50176      |
# | train/                  |            |
# |    approx_kl            | 0.00183374 |
# |    clip_fraction        | 0.0308     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0917    |
# |    explained_variance   | 0.574      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.738      |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.00228   |
# |    value_loss           | 1.03       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91           |
# |    ep_rew_mean          | 9.04         |
# | time/                   |              |
# |    fps                  | 397          |
# |    iterations           | 50           |
# |    time_elapsed         | 128          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0015243687 |
# |    clip_fraction        | 0.0341       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0755      |
# |    explained_variance   | 0.616        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.779        |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00304     |
# |    value_loss           | 1.03         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90.2         |
# |    ep_rew_mean          | 8.93         |
# | time/                   |              |
# |    fps                  | 398          |
# |    iterations           | 51           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 52224        |
# | train/                  |              |
# |    approx_kl            | 0.0028111567 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0781      |
# |    explained_variance   | 0.517        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.547        |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -1.25e-05    |
# |    value_loss           | 1.08         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.5        |
# |    ep_rew_mean          | 8.85        |
# | time/                   |             |
# |    fps                  | 398         |
# |    iterations           | 52          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.006489246 |
# |    clip_fraction        | 0.0458      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0661     |
# |    explained_variance   | 0.648       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.501       |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00517    |
# |    value_loss           | 0.911       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.6        |
# |    ep_rew_mean          | 8.72        |
# | time/                   |             |
# |    fps                  | 399         |
# |    iterations           | 53          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 54272       |
# | train/                  |             |
# |    approx_kl            | 0.032701977 |
# |    clip_fraction        | 0.0991      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.134      |
# |    explained_variance   | 0.165       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.82        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00934    |
# |    value_loss           | 1.58        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 82.5         |
# |    ep_rew_mean          | 7.96         |
# | time/                   |              |
# |    fps                  | 399          |
# |    iterations           | 54           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0013790105 |
# |    clip_fraction        | 0.0411       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.12        |
# |    explained_variance   | 0.462        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.582        |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00195     |
# |    value_loss           | 1.32         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# ...
# |    total_timesteps      | 483328      |
# | train/                  |             |
# |    approx_kl            | 0.005752679 |
# |    clip_fraction        | 0.0449      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0822     |
# |    explained_variance   | 0.638       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04        |
# |    n_updates            | 4710        |
# |    policy_gradient_loss | -0.00154    |
# |    value_loss           | 1.91        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 166          |
# |    ep_rew_mean          | 18.3         |
# | time/                   |              |
# |    fps                  | 401          |
# |    iterations           | 473          |
# |    time_elapsed         | 1206         |
# |    total_timesteps      | 484352       |
# | train/                  |              |
# |    approx_kl            | 0.0019245929 |
# |    clip_fraction        | 0.0328       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.092       |
# |    explained_variance   | 0.609        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.375        |
# |    n_updates            | 4720         |
# |    policy_gradient_loss | -2.45e-05    |
# |    value_loss           | 1.01         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 168          |
# |    ep_rew_mean          | 18.6         |
# | time/                   |              |
# |    fps                  | 401          |
# |    iterations           | 474          |
# |    time_elapsed         | 1208         |
# |    total_timesteps      | 485376       |
# | train/                  |              |
# |    approx_kl            | 0.0038900273 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0698      |
# |    explained_variance   | 0.525        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.28         |
# |    n_updates            | 4730         |
# |    policy_gradient_loss | -0.00231     |
# |    value_loss           | 2.26         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 168          |
# |    ep_rew_mean          | 18.5         |
# | time/                   |              |
# |    fps                  | 402          |
# |    iterations           | 475          |
# |    time_elapsed         | 1209         |
# |    total_timesteps      | 486400       |
# | train/                  |              |
# |    approx_kl            | 0.0030086585 |
# |    clip_fraction        | 0.0259       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0684      |
# |    explained_variance   | 0.555        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.854        |
# |    n_updates            | 4740         |
# |    policy_gradient_loss | 0.0003       |
# |    value_loss           | 1.59         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 166         |
# |    ep_rew_mean          | 18.3        |
# | time/                   |             |
# |    fps                  | 402         |
# |    iterations           | 476         |
# |    time_elapsed         | 1211        |
# |    total_timesteps      | 487424      |
# | train/                  |             |
# |    approx_kl            | 0.001086902 |
# |    clip_fraction        | 0.0297      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0704     |
# |    explained_variance   | 0.513       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.277       |
# |    n_updates            | 4750        |
# |    policy_gradient_loss | 0.00206     |
# |    value_loss           | 1.41        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 169         |
# |    ep_rew_mean          | 18.8        |
# | time/                   |             |
# |    fps                  | 402         |
# |    iterations           | 477         |
# |    time_elapsed         | 1213        |
# |    total_timesteps      | 488448      |
# | train/                  |             |
# |    approx_kl            | 0.005115036 |
# |    clip_fraction        | 0.0403      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0867     |
# |    explained_variance   | 0.652       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.262       |
# |    n_updates            | 4760        |
# |    policy_gradient_loss | -0.000745   |
# |    value_loss           | 1.06        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 177          |
# |    ep_rew_mean          | 19.8         |
# | time/                   |              |
# |    fps                  | 402          |
# |    iterations           | 478          |
# |    time_elapsed         | 1214         |
# |    total_timesteps      | 489472       |
# | train/                  |              |
# |    approx_kl            | 0.0011900616 |
# |    clip_fraction        | 0.0201       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0738      |
# |    explained_variance   | 0.68         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.609        |
# |    n_updates            | 4770         |
# |    policy_gradient_loss | -0.00128     |
# |    value_loss           | 1.23         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 20.1         |
# | time/                   |              |
# |    fps                  | 403          |
# |    iterations           | 479          |
# |    time_elapsed         | 1216         |
# |    total_timesteps      | 490496       |
# | train/                  |              |
# |    approx_kl            | 0.0018719173 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0757      |
# |    explained_variance   | 0.533        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.18         |
# |    n_updates            | 4780         |
# |    policy_gradient_loss | 0.000356     |
# |    value_loss           | 2.07         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 178          |
# |    ep_rew_mean          | 19.8         |
# | time/                   |              |
# |    fps                  | 403          |
# |    iterations           | 480          |
# |    time_elapsed         | 1217         |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0024889375 |
# |    clip_fraction        | 0.0302       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0699      |
# |    explained_variance   | 0.646        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.356        |
# |    n_updates            | 4790         |
# |    policy_gradient_loss | -0.000428    |
# |    value_loss           | 0.949        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 183          |
# |    ep_rew_mean          | 20.4         |
# | time/                   |              |
# |    fps                  | 403          |
# |    iterations           | 481          |
# |    time_elapsed         | 1219         |
# |    total_timesteps      | 492544       |
# | train/                  |              |
# |    approx_kl            | 0.0017268136 |
# |    clip_fraction        | 0.0298       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0767      |
# |    explained_variance   | 0.77         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.582        |
# |    n_updates            | 4800         |
# |    policy_gradient_loss | 0.000309     |
# |    value_loss           | 1.29         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 173         |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 404         |
# |    iterations           | 482         |
# |    time_elapsed         | 1220        |
# |    total_timesteps      | 493568      |
# | train/                  |             |
# |    approx_kl            | 0.005808372 |
# |    clip_fraction        | 0.0289      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0776     |
# |    explained_variance   | 0.648       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.408       |
# |    n_updates            | 4810        |
# |    policy_gradient_loss | 0.000893    |
# |    value_loss           | 1.2         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 165          |
# |    ep_rew_mean          | 18.2         |
# | time/                   |              |
# |    fps                  | 404          |
# |    iterations           | 483          |
# |    time_elapsed         | 1222         |
# |    total_timesteps      | 494592       |
# | train/                  |              |
# |    approx_kl            | 0.0027629226 |
# |    clip_fraction        | 0.0328       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0711      |
# |    explained_variance   | 0.665        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.29         |
# |    n_updates            | 4820         |
# |    policy_gradient_loss | 0.00302      |
# |    value_loss           | 1.64         |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 163       |
# |    ep_rew_mean          | 17.9      |
# | time/                   |           |
# |    fps                  | 404       |
# |    iterations           | 484       |
# |    time_elapsed         | 1224      |
# |    total_timesteps      | 495616    |
# | train/                  |           |
# |    approx_kl            | 0.0070773 |
# |    clip_fraction        | 0.0486    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.113    |
# |    explained_variance   | 0.616     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.05      |
# |    n_updates            | 4830      |
# |    policy_gradient_loss | -0.00405  |
# |    value_loss           | 2.41      |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 168          |
# |    ep_rew_mean          | 18.6         |
# | time/                   |              |
# |    fps                  | 405          |
# |    iterations           | 485          |
# |    time_elapsed         | 1225         |
# |    total_timesteps      | 496640       |
# | train/                  |              |
# |    approx_kl            | 0.0035669738 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0942      |
# |    explained_variance   | 0.54         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.736        |
# |    n_updates            | 4840         |
# |    policy_gradient_loss | 0.000141     |
# |    value_loss           | 1.84         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 174          |
# |    ep_rew_mean          | 19.3         |
# | time/                   |              |
# |    fps                  | 405          |
# |    iterations           | 486          |
# |    time_elapsed         | 1227         |
# |    total_timesteps      | 497664       |
# | train/                  |              |
# |    approx_kl            | 0.0017853165 |
# |    clip_fraction        | 0.0194       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0686      |
# |    explained_variance   | 0.127        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.772        |
# |    n_updates            | 4850         |
# |    policy_gradient_loss | -0.00236     |
# |    value_loss           | 1.82         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 172          |
# |    ep_rew_mean          | 19.1         |
# | time/                   |              |
# |    fps                  | 405          |
# |    iterations           | 487          |
# |    time_elapsed         | 1228         |
# |    total_timesteps      | 498688       |
# | train/                  |              |
# |    approx_kl            | 0.0038307493 |
# |    clip_fraction        | 0.0423       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0868      |
# |    explained_variance   | 0.369        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.21         |
# |    n_updates            | 4860         |
# |    policy_gradient_loss | 0.00113      |
# |    value_loss           | 2.06         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 182         |
# |    ep_rew_mean          | 20.3        |
# | time/                   |             |
# |    fps                  | 406         |
# |    iterations           | 488         |
# |    time_elapsed         | 1230        |
# |    total_timesteps      | 499712      |
# | train/                  |             |
# |    approx_kl            | 0.002396512 |
# |    clip_fraction        | 0.0337      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0809     |
# |    explained_variance   | 0.441       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05        |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | -0.00157    |
# |    value_loss           | 1.3         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 182          |
# |    ep_rew_mean          | 20.3         |
# | time/                   |              |
# |    fps                  | 406          |
# |    iterations           | 489          |
# |    time_elapsed         | 1232         |
# |    total_timesteps      | 500736       |
# | train/                  |              |
# |    approx_kl            | 0.0036866749 |
# |    clip_fraction        | 0.0341       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0732      |
# |    explained_variance   | 0.437        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.313        |
# |    n_updates            | 4880         |
# |    policy_gradient_loss | -0.00101     |
# |    value_loss           | 1.8          |
# ------------------------------------------
# c:\Users\F20ludTob\.conda\envs\Reinforcement\lib\site-packages\stable_baselines3\common\save_util.py:284: UserWarning: Path 'models' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")
